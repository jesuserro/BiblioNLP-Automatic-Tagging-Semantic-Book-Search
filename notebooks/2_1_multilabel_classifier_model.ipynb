# %% [markdown]
# ## ¿Qué quieres hacer?
# - Etiquetar libros (Clasificar).
# - Recomendar títulos de libros a través de etiquetas o palabras.
# - Hacer agrupaciones de libros por categorías (Agrupar => Clasificar de otra manera).
# - Estudiar el sentimiento de los libros.
#
# ## 🔍 ¿Para qué sirve el modelo `"sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"`?
#
# Este modelo **convierte textos (frases, párrafos, etc.) en vectores numéricos** llamados *embeddings*. Estos vectores capturan el significado del texto y permiten hacer tareas como:
#
# - Comparar si dos frases significan lo mismo (detección de paráfrasis).
# - Buscar textos similares (búsqueda semántica).
# - Agrupar frases por tema (clustering).
# - Usarlo como input para modelos de ML que necesiten comprensión semántica del texto.
#
# Además, es **multilingüe**, es decir, funciona con muchos idiomas (inglés, español, francés, etc.).
#
# ---
#
# ## 🛠️ ¿Cómo se usa?
#
# ### 1. Instalación de librerías necesarias:
#
# ```bash
# pip install sentence-transformers
# ```
#
# ### 2. Código básico de uso:
#
# ```python
# from sentence_transformers import SentenceTransformer
#
# # Cargar el modelo
# model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')
#
# # Lista de textos a convertir
# texts = ["Hola, ¿cómo estás?", "Hello, how are you?", "Estoy muy bien, gracias."]
#
# # Obtener embeddings (vectores numéricos)
# embeddings = model.encode(texts)
#
# print(embeddings.shape)  # (3, 384)
# ```
#
# Cada texto se convierte en un vector de 384 dimensiones que representa su significado.
#
# ---
#
# ## 🔡 Parámetros de entrada (input)
#
# El modelo toma como **entrada una lista de strings**:
#
# ```python
# texts = ["Texto 1", "Texto 2", ...]
# ```
#
# - Puedes pasarle solo **una frase** o **una lista de frases**.
# - Los textos pueden estar en **cualquier idioma soportado** (incluye español).
#
# ---
#
# ## 🎯 Salida (output)
#
# La salida es una **matriz de embeddings**:
#
# ```python
# [
#   [0.1, -0.05, ..., 0.23],  # Embedding del primer texto
#   [0.03, 0.12, ..., -0.17], # Embedding del segundo texto
#   ...
# ]
# ```
#
# Cada texto se convierte en un vector de **384 números** (`float32`), que puedes usar para:
#
# - Comparar similitud entre textos con `cosine_similarity`.
# - Entrenar modelos de clasificación o clustering.
# - Visualización en 2D (reduciendo dimensiones con PCA o t-SNE).
#
# ---
#
# ## 🧠 Casos de uso reales
#
# | Caso | Entrada | Uso del output |
# |------|---------|----------------|
# | Detección de duplicados | 2 frases | Comparas los vectores con *cosine similarity* |
# | Búsqueda semántica | Texto y base de datos de textos | Vectorizas todo y buscas el más cercano |
# | Clasificación | Texto + etiquetas | Vectorizas y entrenas un modelo ML clásico |
# | Clustering | Lista de textos | Agrupas los vectores con KMeans o similares |

# %%
# %pip install sentence_transformers
# %pip install fastapi
# %pip install uvicorn
# %pip install scikit-learn
# %pip install joblib
# %pip install wordcloud
# %pip install termcolor

# %%
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.multioutput import MultiOutputClassifier
from sentence_transformers import SentenceTransformer
from sklearn.metrics import classification_report
from sklearn.exceptions import UndefinedMetricWarning
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import auc as sklearn_auc  # renombramos por seguridad
import numpy as np
import joblib
import os
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
import nltk
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from termcolor import colored
import warnings

# Descargar stopwords de nltk si no están disponibles
# nltk.download('stopwords')

# Combinar stopwords de nltk con otras posibles palabras irrelevantes
my_stop_words = {'to-read', 'closed', 'abandoned-books'
'rating-top', 'literature', 'not-interested', 'libricos', 'recommended',
'000-next', 
'001-ladder-top', '002-ladder-short-term', '003-ladder-medium-term', '004-ladder-long-term', 
'005-ladder-maybe-someday', 
'_cristina', '_giorgia', '_natalia', '_nieves', '_pilar', '_sindy', '_víctor', 'chełmińska'
}
stop_words = set(my_stop_words)
stop_words = stop_words.union(set(stopwords.words('english')))
stop_words = stop_words.union(set(stopwords.words('spanish')))
stop_words = stop_words.union(set(stopwords.words('french')))
stop_words = stop_words.union(set(stopwords.words('italian')))

# 1. Cargar el dataset
df = pd.read_csv('../data/processed/books.csv')

# 2. Combinar título y blurb como entrada textual
df['text'] = df['book_title'].fillna('') + '. ' + df['blurb'].fillna('')

# 3. Procesar los tags: convertirlos en listas y filtrar stop-words
def filter_stopwords(tags):
    """
    Filtra las stop-words de una lista de etiquetas.
    """
    return [tag for tag in tags if tag.lower() not in stop_words]

df['tags'] = df['tags'].apply(lambda x: filter_stopwords([t.strip() for t in str(x).split(',')]))

# 4. Binarización multilabel
mlb = MultiLabelBinarizer()
Y = mlb.fit_transform(df['tags'])

# 5. Generar embeddings con un modelo multilingüe
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
X_embeddings = model.encode(df['text'].tolist(), show_progress_bar=True)

# Cada texto se convierte en un vector de 384 dimensiones que representa su significado.
print(X_embeddings.shape)

# Muestra los 5 primeros embeddings
print(X_embeddings[:5])
# Out:
# Batches:   0%|          | 0/37 [00:00<?, ?it/s]
# (1160, 384)
# [[ 0.02750626  0.24533911 -0.28562394 ... -0.07536055 -0.11509603
#   -0.052958  ]
#  [ 0.13428229  0.19359675 -0.12010901 ...  0.17271587 -0.02152544
#    0.20994484]
#  [-0.08193501  0.13613778 -0.3626985  ... -0.0060622   0.02430391
#   -0.10530125]
#  [-0.08946097  0.22455171 -0.21121377 ...  0.11752453  0.10014538
#    0.09203939]
#  [ 0.03017087  0.09743527 -0.2866786  ...  0.05749123  0.04960755
#    0.03592228]]

# %%
# 6. Entrenar modelo multilabel
clf = MultiOutputClassifier(LogisticRegression(max_iter=1000))
clf.fit(X_embeddings, Y)

# 7. Guardar modelo y objetos necesarios
joblib.dump(clf, '../model/book_tagging_pipeline.joblib')
joblib.dump(mlb, '../model/book_tagging_pipeline_mlb.joblib')
joblib.dump(model, '../model/book_tagging_pipeline_sentence_bert.joblib')

# ...existing code...

# 8. Función para predecir tags de nuevos libros
def predict_tags(titles, blurbs, threshold=0.3, stop_words=None):
    """
    Predice etiquetas para nuevos libros.
    
    Args:
        titles (list): Lista de títulos de libros.
        blurbs (list): Lista de descripciones de libros.
        threshold (float): Umbral para convertir probabilidades en etiquetas binarias.
        stop_words (set): Conjunto de etiquetas que deben ser filtradas.
        
    Returns:
        list: Lista de listas con las etiquetas predichas (sin las stop words).
    """
    if stop_words is None:
        stop_words = set()  # Si no se proporcionan stop words, usar un conjunto vacío.
    
    texts = [t + '. ' + b for t, b in zip(titles, blurbs)]
    X_test = model.encode(texts)
    
    # Obtener las probabilidades de predicción
    preds_proba = np.array([proba[:, 1] for proba in clf.predict_proba(X_test)]).T
    
    # Aplicar el umbral para convertir probabilidades en etiquetas binarias
    preds = (preds_proba >= threshold).astype(int)
    
    # Invertir la binarización para obtener las etiquetas originales
    tag_lists = mlb.inverse_transform(preds)
    
    # Filtrar las etiquetas que están en stop_words
    filtered_tags = [[tag for tag in tags if tag not in stop_words] for tags in tag_lists]
    return filtered_tags

# %%
# Ejemplo de predicción de un libro inventado
new_titles = ["La conspiración del universo"]
new_blurbs = ["Una historia que entrelaza ciencia, fe y filosofía para revelar los secretos de la creación."]
predicted_tags = predict_tags(new_titles, new_blurbs, threshold=0.3, stop_words=my_stop_words)
print(predicted_tags)
# Out:
# [['astronomy', 'philosophy', 'religion', 'science']]

# %%
# Ejemplo generación de embeddings para la "Isla del Tesoro" en inglés
new_titles = ["Treasure Island"]
new_blurbs = ["Treasure Island is an adventure novel by Scottish author Robert Louis Stevenson, narrating a tale of buccaneers and buried gold."]
predicted_tags = predict_tags(new_titles, new_blurbs, threshold=0.3, stop_words=my_stop_words)
print(predicted_tags)
# Out:
# [['catholic', 'classics', 'fiction', 'literary-criticism']]

# %%
# Ejemplo generación de embeddings para la "Isla del Tesoro" en español
new_titles = ["La isla del tesoro"]
new_blurbs = ["La isla del tesoro es una novela de aventuras del autor escocés Robert Louis Stevenson, que narra una historia de bucaneros y oro enterrado."]
predicted_tags = predict_tags(new_titles, new_blurbs, threshold=0.3, stop_words=my_stop_words)
print(predicted_tags)
# Out:
# [['catholic', 'classics', 'fiction', 'literary-criticism']]

# %%
# Ejemplo generación de embeddings para "El Quijote"
new_titles = ["Don Quijote de la Mancha"]
new_blurbs = ["Don Quijote de la Mancha es una novela escrita por el español Miguel de Cervantes Saavedra. Publicada su primera parte con el título de El ingenioso hidalgo don Quijote de la Mancha a comienzos de 1605, es una de las obras más destacadas de la literatura española y la literatura universal."]
predicted_tags = predict_tags(new_titles, new_blurbs, threshold=0.3, stop_words=my_stop_words)
print(predicted_tags)
# Out:
# [['catholic', 'classics', 'spain']]

# %%
# Ejemplo de predicción de etiquetas
new_titles = ["La conspiración del universo", "El arte de la guerra", "Cien años de soledad"]
new_blurbs = [
    "Una historia que entrelaza ciencia, fe y filosofía para revelar los secretos de la creación.",
    "Un tratado clásico sobre estrategia militar y liderazgo.",
    "Una obra maestra de la literatura que explora la historia de una familia en un pueblo ficticio."
]
predicted_tags = predict_tags(new_titles, new_blurbs, threshold=0.3, stop_words=my_stop_words)

# Print each item in a new line
for tags in predicted_tags:
    print(tags)
# Out:
# ['astronomy', 'philosophy', 'religion', 'science']
# ['communism', 'history', 'rating-top', 'war']
# ['children', 'christianity', 'classics', 'fiction', 'memoir']

# %%
# Contar la frecuencia de las etiquetas
all_tags = [tag for tags in predicted_tags for tag in tags]
tag_counts = Counter(all_tags)

# Generar la nube de palabras
wordcloud = WordCloud(width=800, height=400, background_color="white").generate_from_frequencies(tag_counts)

# Mostrar la nube de palabras
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Predicted Word Cloud", fontsize=14, color='green')
plt.tight_layout()
plt.savefig('../img/tag_wordcloud.jpg')
plt.show()

# %%
# 9. Dividir el dataset en entrenamiento (80%) y evaluación (20%)
df_train, df_test, Y_train, Y_test = train_test_split(df, Y, test_size=0.2, random_state=42)

# Verificar etiquetas en Y_train
valid_labels = np.any(Y_train, axis=0) & np.any(~Y_train, axis=0)  # Etiquetas con al menos un 0 y un 1
Y_train = Y_train[:, valid_labels]  # Filtrar etiquetas problemáticas
Y_test = Y_test[:, valid_labels]    # Ajustar también el conjunto de prueba
mlb.classes_ = mlb.classes_[valid_labels]  # Actualizar las clases del binarizador


# Reentrenar el modelo con el conjunto de entrenamiento
X_train_embeddings = model.encode(df_train['text'].tolist(), show_progress_bar=True)
clf.fit(X_train_embeddings, Y_train)
# Out:
# Batches:   0%|          | 0/29 [00:00<?, ?it/s]
# MultiOutputClassifier(estimator=LogisticRegression(max_iter=1000))

# %%
# 10. Evaluar el modelo con el conjunto de prueba
X_test_embeddings = model.encode(df_test['text'].tolist(), show_progress_bar=True)
Y_pred = clf.predict(X_test_embeddings)

# Calcular el score y el % de aciertos
print("Classification Report:")
print(classification_report(Y_test, Y_pred, target_names=mlb.classes_))
# Out:
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Classification Report:
#                              precision    recall  f1-score   support
#
#                16th-century       0.00      0.00      0.00         0
#                18th-century       0.00      0.00      0.00         0
#                19th-century       0.00      0.00      0.00         0
#                20th-century       0.00      0.00      0.00         1
#          abandonment-in-god       0.00      0.00      0.00         2
#                    abortion       0.00      0.00      0.00         0
#                  acceptance       0.00      0.00      0.00         1
#            action-adventure       0.00      0.00      0.00         0
#                 adolescence       0.00      0.00      0.00         3
#                      adults       0.00      0.00      0.00         0
#                      advent       0.00      0.00      0.00         0
#                  adventures       0.00      0.00      0.00         8
#                      africa       0.00      0.00      0.00         4
#       afterlife-experiences       0.00      0.00      0.00         0
#                       aging       0.00      0.00      0.00         0
#                 agriculture       0.00      0.00      0.00         2
#                    alacoque       0.00      0.00      0.00         0
#                      aliens       0.00      0.00      0.00         0
#                  allegories       0.00      0.00      0.00         5
#                   alzheimer       0.00      0.00      0.00         0
#                     america       0.00      0.00      0.00         3
#          ancient-literature       0.00      0.00      0.00         1
#                      angels       0.00      0.00      0.00         1
#                 anglicanism       0.00      0.00      0.00         2
#                     anguish       0.00      0.00      0.00         0
#                     animals       0.00      0.00      0.00         0
#                anthropology       0.00      0.00      0.00         1
#              anti-catholics       0.00      0.00      0.00         3
#                  antichrist       0.00      0.00      0.00         0
#                     anxiety       1.00      0.33      0.50         3
#                  apocalypse       0.00      0.00      0.00         0
#                 apologetics       0.00      0.00      0.00         3
#                    apostasy       0.00      0.00      0.00         0
#                    apostles       0.00      0.00      0.00         1
#                 apparitions       1.00      1.00      1.00         3
#                 archaeology       0.00      0.00      0.00         2
#                  archetypes       0.00      0.00      0.00         0
#                architecture       0.00      0.00      0.00         0
#                   arguments       0.00      0.00      0.00         0
#                   aristotle       0.00      0.00      0.00         0
#                ars-moriendi       0.00      0.00      0.00         2
#                         art       0.67      0.50      0.57         4
#                 art-history       0.00      0.00      0.00         1
#                      art-of       0.00      0.00      0.00         2
#                  asceticism       0.00      0.00      0.00         2
#                        asia       0.00      0.00      0.00         6
#                   astrology       0.00      0.00      0.00         0
#                   astronomy       1.00      0.20      0.33         5
#                     atheism       0.00      0.00      0.00         4
#                  audiobooks       0.00      0.00      0.00         5
#                      autism       0.00      0.00      0.00         0
#               award-winning       0.00      0.00      0.00         1
#                  baby-jesus       0.00      0.00      0.00         0
#            beatific-visions       1.00      0.20      0.33         5
#                   beatified       0.00      0.00      0.00         1
#                  beatitudes       0.00      0.00      0.00         0
#                      beauty       0.00      0.00      0.00         1
#                benedictines       0.00      0.00      0.00         0
#                  bestseller       0.00      0.00      0.00         1
#                       bible       0.75      0.30      0.43        10
#                   biography       0.91      0.33      0.49        30
#                     biology       0.00      0.00      0.00         0
#                black-legend       0.00      0.00      0.00         0
#                   blessings       0.00      0.00      0.00         1
#                       books       0.00      0.00      0.00         1
#                      bosnia       0.00      0.00      0.00         0
#                      botany       0.00      0.00      0.00         1
#                    buddhism       0.00      0.00      0.00         0
#                    business       0.00      0.00      0.00         4
#                   capuchins       0.00      0.00      0.00         0
#                        care       0.00      0.00      0.00         0
#                  carmelites       0.00      0.00      0.00         0
#                  cathedrals       0.00      0.00      0.00         0
#                    catholic       0.67      0.64      0.65        88
#            challenging-read       0.00      0.00      0.00         1
#                     changes       0.00      0.00      0.00         0
#                     charity       0.00      0.00      0.00         3
#                    chastity       0.00      0.00      0.00         1
#                       chess       0.00      0.00      0.00         0
#                   childhood       0.00      0.00      0.00         0
#                    children       1.00      0.27      0.43        11
#                       china       0.00      0.00      0.00         0
#                      christ       0.55      0.43      0.48        14
#                christianity       0.33      0.07      0.12        27
#                   christmas       0.00      0.00      0.00         1
#                      church       0.00      0.00      0.00         1
#              church-history       0.00      0.00      0.00        21
#                   civil-war       0.00      0.00      0.00         0
#                civilization       0.00      0.00      0.00         0
#                    classics       0.44      0.12      0.20        32
#              climate-change       0.00      0.00      0.00         0
#                 coexistence       0.00      0.00      0.00         0
#                     comfort       0.00      0.00      0.00         1
#                      comics       1.00      0.50      0.67         4
#               communication       0.00      0.00      0.00         2
#                   communism       0.67      0.20      0.31        10
#                  compassion       0.00      0.00      0.00         0
#               concentration       0.00      0.00      0.00         0
#                  confession       0.00      0.00      0.00         0
#               contemplation       0.00      0.00      0.00         0
#                contemporary       0.00      0.00      0.00         0
#                 conversions       0.00      0.00      0.00         1
#                     courage       0.00      0.00      0.00         1
#                   courtship       0.00      0.00      0.00         2
#            covenants-of-god       0.00      0.00      0.00         0
#                    creation       0.00      0.00      0.00         2
#                       creed       0.00      0.00      0.00         2
#                       crime       0.00      0.00      0.00         0
#                       cross       0.00      0.00      0.00         1
#       daily-chapter-reading       0.00      0.00      0.00         1
#                       death       0.00      0.00      0.00         8
#                     decline       0.00      0.00      0.00         1
#                  decoration       0.00      0.00      0.00         1
#                      demons       0.00      0.00      0.00         2
#                     denmark       0.00      0.00      0.00         0
#                  depression       0.00      0.00      0.00         1
#                     deserts       0.00      0.00      0.00         0
#                  devotional       0.29      0.25      0.27        16
#       dialogues-with-christ       0.00      0.00      0.00         4
#                       diets       0.00      0.00      0.00         0
#                 discernment       0.00      0.00      0.00         0
#                divine-mercy       0.00      0.00      0.00         0
#                    doctrine       0.00      0.00      0.00         0
#                      dogmas       1.00      0.20      0.33         5
#                       doubt       0.00      0.00      0.00         0
#                       drama       0.00      0.00      0.00         1
#                     economy       0.00      0.00      0.00         1
#                   education       0.00      0.00      0.00         3
#                       egypt       0.00      0.00      0.00         0
#                       emaus       0.00      0.00      0.00         0
#     emotional-relationships       0.00      0.00      0.00         4
#                     empires       0.00      0.00      0.00         0
#                 encyclicals       0.00      0.00      0.00         1
#            english-language       0.00      0.00      0.00         1
#                  entomology       0.00      0.00      0.00         1
#            environmentalism       0.00      0.00      0.00         0
#                        epic       0.00      0.00      0.00         0
#                      erotic       0.00      0.00      0.00         0
#                      essays       0.00      0.00      0.00         6
#                    eternity       0.00      0.00      0.00         1
#                   eucharist       0.00      0.00      0.00         3
#                      europe       0.00      0.00      0.00         2
#                evangelicals       0.00      0.00      0.00         2
#               everyday-life       0.00      0.00      0.00         0
#                   evolution       0.00      0.00      0.00         1
#                    exegesis       0.00      0.00      0.00         1
#            existence-of-god       0.00      0.00      0.00         2
#              existentialism       0.00      0.00      0.00         0
#                      fables       0.00      0.00      0.00         1
#                       faith       0.00      0.00      0.00        23
#                      family       0.00      0.00      0.00         4
#                     fantasy       0.00      0.00      0.00         1
#                     fasting       0.00      0.00      0.00         1
#                  fatherhood       0.00      0.00      0.00         1
#                      fatima       0.00      0.00      0.00         1
#                   favorites       0.00      0.00      0.00         5
#                       fears       0.00      0.00      0.00         1
#                  femininity       0.00      0.00      0.00         0
#                    feminism       0.00      0.00      0.00         1
#                     fiction       0.67      0.44      0.53        27
#                        film       0.00      0.00      0.00         3
#              film-criticism       0.00      0.00      0.00         0
#                 forgiveness       0.00      0.00      0.00         0
#                   fragility       0.00      0.00      0.00         1
#                      france       1.00      0.12      0.22         8
#                 franciscans       0.00      0.00      0.00         1
#                     freedom       0.00      0.00      0.00         1
#                  friendship       0.00      0.00      0.00         2
#                       games       0.00      0.00      0.00         0
#                  garabaldal       0.00      0.00      0.00         0
#                   gardening       0.00      0.00      0.00         0
#                  gastronomy       0.00      0.00      0.00         2
#                gate-parable       0.00      0.00      0.00         0
#             gender-ideology       0.00      0.00      0.00         1
#                     genesis       0.00      0.00      0.00         3
#                   genocides       0.00      0.00      0.00         0
#                     germany       0.00      0.00      0.00         1
#                  gethsemane       0.00      0.00      0.00         0
#                       gifts       0.00      0.00      0.00         0
#                   globalism       0.00      0.00      0.00         1
#                  god-exists       0.00      0.00      0.00         0
#                     gospels       0.00      0.00      0.00         3
#                      gothic       0.00      0.00      0.00         0
#                       grace       0.00      0.00      0.00         0
#                   gratitude       0.00      0.00      0.00         0
#                       greek       0.00      0.00      0.00         0
#            greek-philosophy       0.00      0.00      0.00         0
#                       grief       0.00      0.00      0.00         1
#                   guadalupe       0.00      0.00      0.00         0
#                       haiku       0.00      0.00      0.00         0
#                   happiness       0.00      0.00      0.00         0
#                     healing       0.00      0.00      0.00         2
#                      health       0.00      0.00      0.00         5
#                       heart       0.00      0.00      0.00         4
#                      heaven       0.00      0.00      0.00         2
#                        hell       0.00      0.00      0.00         1
#                     hermits       0.00      0.00      0.00         0
#                   himalayas       0.00      0.00      0.00         6
#               hispanophobia       0.00      0.00      0.00         0
#             historiascortas       0.00      0.00      0.00         0
#                  historical       0.00      0.00      0.00         4
#          historical-fiction       0.00      0.00      0.00         2
#                     history       0.78      0.33      0.47        21
#                    holiness       0.00      0.00      0.00         4
#                   holocaust       0.00      0.00      0.00         0
#                   holy-face       0.00      0.00      0.00         0
#                 holy-family       0.00      0.00      0.00         0
#                 holy-spirit       0.00      0.00      0.00         3
#                holy-trinity       0.00      0.00      0.00         2
#                        home       0.00      0.00      0.00         0
#                        hope       0.00      0.00      0.00         6
#                      horror       0.00      0.00      0.00         1
#                   hospitals       0.00      0.00      0.00         0
#                    humanism       0.00      0.00      0.00         1
#                    humility       0.00      0.00      0.00         4
#                       humor       0.00      0.00      0.00         3
#                 iconography       0.00      0.00      0.00         0
#                    identity       0.00      0.00      0.00         3
#                  ideologies       0.00      0.00      0.00         1
#                     illness       0.00      0.00      0.00         2
#                 illustrated       0.00      0.00      0.00        10
#                 inner-peace       0.00      0.00      0.00         0
#                 inquisition       0.00      0.00      0.00         0
#               inspirational       0.00      0.00      0.00         2
#                intelligence       0.00      0.00      0.00         0
#          intelligent-design       0.00      0.00      0.00         0
#                 interesting       0.00      0.00      0.00         0
#         interesting-authors       0.00      0.00      0.00         0
#               introspection       0.00      0.00      0.00         0
#                       irony       0.00      0.00      0.00         1
#                    islamism       0.00      0.00      0.00         4
#                      israel       0.00      0.00      0.00         4
#                       italy       1.00      0.20      0.33         5
#                       jacob       0.00      0.00      0.00         0
#                       japan       0.00      0.00      0.00         1
#                     jesuits       0.00      0.00      0.00         0
#                         job       0.00      0.00      0.00         2
#                       jonah       0.00      0.00      0.00         3
#                  journalism       0.00      0.00      0.00         0
#                         joy       0.00      0.00      0.00         0
#                     judaism       0.00      0.00      0.00         2
#                    kowalska       0.00      0.00      0.00         0
#                      ladder       0.00      0.00      0.00         2
#                    languaje       0.00      0.00      0.00         0
#                         law       0.00      0.00      0.00         1
#                  leadership       0.00      0.00      0.00         2
#               lectio-divina       0.00      0.00      0.00         0
#                     lectura       0.00      0.00      0.00         0
#                   left-wing       0.00      0.00      0.00         1
#                     leisure       0.00      0.00      0.00         0
#                        lent       0.33      0.12      0.18         8
#                   leviticus       0.00      0.00      0.00         0
#                       leyes       0.00      0.00      0.00         1
#                   lifestyle       0.00      0.00      0.00         3
#                       light       0.00      0.00      0.00         0
#               light-reading       0.00      0.00      0.00         2
#                      limits       0.00      0.00      0.00         1
#          literary-criticism       0.00      0.00      0.00         3
#           livestock-farming       0.00      0.00      0.00         0
#                  loneliness       0.00      0.00      0.00         2
#           lord-of-the-rings       0.00      0.00      0.00         2
#                        loss       0.00      0.00      0.00         1
#                     lourdes       0.00      0.00      0.00         1
#                        love       1.00      0.08      0.15        12
#                        maps       0.00      0.00      0.00         1
#                    marriage       0.00      0.00      0.00         8
#                   martyrdom       0.00      0.00      0.00         6
#                 masculinity       0.00      0.00      0.00         3
#                 mathematics       0.00      0.00      0.00         0
#                    maturity       0.00      0.00      0.00         0
#             meaning-of-life       0.00      0.00      0.00         1
#                    medicine       0.00      0.00      0.00         0
#                    medieval       0.00      0.00      0.00         4
#                 meditations       0.00      0.00      0.00         4
#                  medjugorje       0.00      0.00      0.00         1
#                  melancholy       0.00      0.00      0.00         0
#                      memoir       0.50      0.14      0.22         7
#                memorization       0.00      0.00      0.00         0
#               mental-health       1.00      0.25      0.40         4
#                       mercy       0.00      0.00      0.00         0
#                 metaphysics       0.00      0.00      0.00         0
#                      mexico       0.00      0.00      0.00         1
#                 middle-east       0.00      0.00      0.00         0
#                        miex       0.80      0.25      0.38        16
#                    miracles       0.00      0.00      0.00         4
#                  misfortune       0.00      0.00      0.00         0
#                     mistery       0.00      0.00      0.00         4
#                   misticism       0.00      0.00      0.00         4
#                   mithology       0.00      0.00      0.00         1
#                     modesty       0.00      0.00      0.00         0
#                  monarchies       0.00      0.00      0.00         0
#                 monasteries       0.00      0.00      0.00         1
#                       monks       0.00      0.00      0.00         7
#                    morality       0.00      0.00      0.00         2
#               mortification       0.00      0.00      0.00         4
#                  motherhood       0.00      0.00      0.00         1
#              mountaineering       1.00      0.12      0.22         8
#                       music       0.00      0.00      0.00         1
#                  my-memoirs       0.00      0.00      0.00         0
#           myths-and-legends       0.00      0.00      0.00         0
#                  narcissism       0.00      0.00      0.00         0
#                      nature       0.00      0.00      0.00         1
#                     navarre       0.00      0.00      0.00         0
#                 netherlands       0.00      0.00      0.00         0
#               new-testament       0.33      0.17      0.22         6
#                      newage       1.00      0.50      0.67         2
#                 nobel-prize       0.00      0.00      0.00         0
#                  nonfiction       0.42      0.09      0.15        55
#                   nostalgia       0.00      0.00      0.00         0
#     not-available-on-kindle       0.00      0.00      0.00         5
#                      novels       0.00      0.00      0.00         2
#                        nuns       1.00      0.50      0.67         4
#                   nutrition       0.00      0.00      0.00         0
#                   obedience       0.00      0.00      0.00         1
#                    ocultism       0.00      0.00      0.00         0
#               old-testament       0.00      0.00      0.00         5
#                    opus-dei       0.00      0.00      0.00         0
#               ordinary-life       0.00      0.00      0.00         1
#         orthodox-christians       0.50      0.33      0.40         3
#                  overcoming       0.00      0.00      0.00         1
#                   padre-pio       0.00      0.00      0.00         0
#                    paganism       0.00      0.00      0.00         0
#                    painting       0.00      0.00      0.00         0
# parable-of-the-prodigal-son       0.00      0.00      0.00         1
#                    parables       0.00      0.00      0.00         6
#                   paradigms       0.00      0.00      0.00         0
#                  paranormal       0.00      0.00      0.00         1
#                       paris       0.00      0.00      0.00         0
#           passion-of-christ       0.00      0.00      0.00         4
#                 passionists       0.00      0.00      0.00         0
#                    patience       0.00      0.00      0.00         0
#                  patriarchs       0.00      0.00      0.00         0
#                  patristics       0.00      0.00      0.00         2
#                      paused       0.00      0.00      0.00         1
#                persecutions       0.00      0.00      0.00         1
#              personal-names       0.00      0.00      0.00         0
#                perspectives       0.00      0.00      0.00         1
#                  philosophy       0.61      0.35      0.45        31
#                     physics       0.00      0.00      0.00         2
#                 pilgrimages       0.00      0.00      0.00         0
#                      poetry       0.80      0.44      0.57         9
#                      poland       0.00      0.00      0.00         2
#                    politics       0.50      0.10      0.17        10
#                       popes       0.00      0.00      0.00         4
#                    portugal       0.00      0.00      0.00         1
#                     poverty       0.00      0.00      0.00         1
#                   practical       0.00      0.00      0.00         0
#                      praise       0.00      0.00      0.00         0
#                      prayer       0.80      0.44      0.57        18
#                   preaching       0.00      0.00      0.00         1
#             presbyterianism       0.00      0.00      0.00         0
#                     present       0.00      0.00      0.00         2
#                       pride       0.00      0.00      0.00         0
#                  priesthood       0.00      0.00      0.00         0
#                     priests       0.00      0.00      0.00         2
#                     prisons       0.00      0.00      0.00         0
#                productivity       0.00      0.00      0.00         2
#                   profecies       0.00      0.00      0.00         4
#                 programming       1.00      0.60      0.75         5
#                    prophets       0.00      0.00      0.00         5
#               protestantism       0.00      0.00      0.00         3
#                      psalms       0.00      0.00      0.00         1
#                  psichology       0.56      0.26      0.36        19
#         psychological-cores       0.00      0.00      0.00         0
#                 psychopathy       0.00      0.00      0.00         0
#          psycological-cores       0.00      0.00      0.00         0
#                   purgatory       0.00      0.00      0.00         3
#                      purity       0.00      0.00      0.00         1
#                  quarantine       0.00      0.00      0.00         4
#                      quotes       0.00      0.00      0.00         0
#           rating-number-top       0.00      0.00      0.00         2
#                  rating-top       0.00      0.00      0.00         7
#                     reading       0.00      0.00      0.00         0
#                     recipes       0.00      0.00      0.00         1
#                  redemption       0.00      0.00      0.00         2
#                   reference       0.00      0.00      0.00         1
#                    religion       0.00      0.00      0.00        28
#                 renaissance       0.00      0.00      0.00         0
#                  repentance       0.00      0.00      0.00         0
#                    research       0.00      0.00      0.00         1
#              responsability       0.00      0.00      0.00         0
#                        rest       0.00      0.00      0.00         0
#                     restart       0.00      0.00      0.00         3
#                resurrection       0.00      0.00      0.00         2
#                  retirement       0.00      0.00      0.00         0
#                  revelation       0.00      0.00      0.00         1
#                reviewed-top       0.00      0.00      0.00         0
#                 revolutions       0.00      0.00      0.00         0
#                       roles       0.00      0.00      0.00         0
#                roman-empire       0.00      0.00      0.00         0
#                     romance       0.00      0.00      0.00         3
#                        rome       0.00      0.00      0.00         0
#                      rosary       0.00      0.00      0.00         1
#                       rural       0.00      0.00      0.00         0
#                      russia       1.00      0.44      0.62         9
#                  sacraments       0.00      0.00      0.00         0
#                      sacred       0.00      0.00      0.00         0
#      sacred-heart-of-christ       0.00      0.00      0.00         0
#                     sadness       0.00      0.00      0.00         0
#     saint-francis-of-assisi       0.00      0.00      0.00         1
#    saint-ignatius-of-loyola       0.00      0.00      0.00         0
#                  saint-john       0.00      0.00      0.00         1
#          saint-john-paul-ii       0.00      0.00      0.00         1
#                saint-joseph       0.00      0.00      0.00         0
#                  saint-luke       0.00      0.00      0.00         0
#               saint-matthew       0.00      0.00      0.00         0
#                  saint-paul       0.00      0.00      0.00         0
#       saint-teresa-of-jesus       0.00      0.00      0.00         1
#        saint-thomas-aquinas       0.00      0.00      0.00         0
#                      saints       1.00      0.08      0.14        13
#                   salvation       0.00      0.00      0.00         0
#   samaritan-woman-of-sychar       0.00      0.00      0.00         0
#                     science       0.70      0.58      0.64        12
#             science-fiction       0.00      0.00      0.00         1
#                    security       0.00      0.00      0.00         0
#        seeing-the-invisible       0.00      0.00      0.00         0
#                   sehnsucht       0.00      0.00      0.00         0
#                  selfesteem       0.00      0.00      0.00         1
#                    selfhelp       0.50      0.08      0.13        13
#                 selfishness       0.00      0.00      0.00         0
#                 sensitivity       0.00      0.00      0.00         0
#                      series       0.00      0.00      0.00         2
#                   sexuality       0.00      0.00      0.00         2
#               short-stories       0.00      0.00      0.00         4
#                     shyness       0.00      0.00      0.00         0
#                     silence       0.00      0.00      0.00         5
#                  simplicity       0.00      0.00      0.00         1
#                  skepticism       0.00      0.00      0.00         0
#                   socialism       0.00      0.00      0.00         4
#                     society       0.00      0.00      0.00         3
#                   sociology       0.00      0.00      0.00         4
#                        soul       0.00      0.00      0.00         0
#                       space       0.00      0.00      0.00         4
#                       spain       0.00      0.00      0.00         4
#            spanish-language       0.00      0.00      0.00         0
#           spiritual-warfare       0.00      0.00      0.00         1
#                spirituality       0.00      0.00      0.00        36
#                      sports       0.00      0.00      0.00         1
#               steadfastness       0.00      0.00      0.00         0
#                    stigmata       0.00      0.00      0.00         0
#                   suffering       0.67      0.12      0.21        16
#                    suspense       0.00      0.00      0.00         0
#                   symbolism       0.00      0.00      0.00         1
#                      talent       0.00      0.00      0.00         0
#                    talented       0.00      0.00      0.00         0
#                  technology       0.00      0.00      0.00         0
#                  temptation       0.00      0.00      0.00         0
#                    tenacity       0.00      0.00      0.00         0
#                 testimonies       0.50      0.08      0.14        12
#                     theatre       0.00      0.00      0.00         0
#                    theology       0.40      0.30      0.34        40
#                    theraphy       0.00      0.00      0.00         2
#                      thirst       0.00      0.00      0.00         1
#                    thoughts       0.00      0.00      0.00         0
#                    thriller       0.00      0.00      0.00         1
#                  traditions       0.00      0.00      0.00         0
#                    training       0.00      0.00      0.00         0
#                      travel       0.00      0.00      0.00         4
#                       trust       0.00      0.00      0.00         0
#                       truth       0.00      0.00      0.00         0
#                         ufo       0.67      0.50      0.57         4
#                          uk       0.00      0.00      0.00         5
#                  university       0.00      0.00      0.00         0
#                         usa       0.00      0.00      0.00         3
#                    vampires       0.00      0.00      0.00         0
#                     vatican       0.00      0.00      0.00         2
#                 virgin-mary       0.86      0.75      0.80         8
#                     virtues       0.00      0.00      0.00         4
#                     visions       0.00      0.00      0.00         3
#                    vocation       0.00      0.00      0.00         2
#                volunteering       0.00      0.00      0.00         0
#               vulnerability       0.00      0.00      0.00         0
#                         war       0.00      0.00      0.00         3
#                      waters       0.00      0.00      0.00         0
#            way-of-the-cross       0.00      0.00      0.00         1
#        western-civilization       0.00      0.00      0.00         0
#                   widowhood       0.00      0.00      0.00         0
#                   witnesses       0.00      0.00      0.00         1
#                        woke       0.00      0.00      0.00         0
#                       women       1.00      0.25      0.40        12
#                       words       0.00      0.00      0.00         1
#                   world-war       0.00      0.00      0.00         1
#                     worship       0.00      0.00      0.00         2
#                      wounds       0.00      0.00      0.00         0
#                     writing       1.00      0.33      0.50         3
#                       youth       0.00      0.00      0.00         0
#
#                   micro avg       0.60      0.16      0.26      1312
#                   macro avg       0.07      0.03      0.04      1312
#                weighted avg       0.35      0.16      0.20      1312
#                 samples avg       0.49      0.22      0.26      1312
# c:\Users\jesus\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\jesus\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\jesus\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\jesus\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\jesus\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\jesus\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in samples with no true nor predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# 11. Comparar predicciones con los tags reales y colorear resultados
def compare_predictions(real_tags, predicted_tags):
    """
    Compara las etiquetas reales con las predichas y las colorea.
    """
    result = []
    for real, predicted in zip(real_tags, predicted_tags):
        comparison = []
        for tag in real:
            if tag in predicted:
                comparison.append(colored(tag, 'green'))  # Acertado
            else:
                comparison.append(colored(tag, 'red'))  # No acertado
        result.append(comparison)
    return result

# Obtener las etiquetas reales y predichas
real_tags = df_test['tags'].tolist()
predicted_tags = predict_tags(df_test['book_title'].tolist(), df_test['blurb'].tolist(), stop_words=stop_words)

# Comparar y mostrar resultados coloreados
colored_results = compare_predictions(real_tags, predicted_tags)
for i, (real, predicted, colored_tags) in enumerate(zip(real_tags, predicted_tags, colored_results)):
    print(f"\nLibro {i + 1}:")
    print(f"Título: {df_test.iloc[i]['book_title']}")
    print(f"Etiquetas reales: {real}")
    print(f"Etiquetas predichas: {predicted}")
    print(f"Comparación coloreada: {', '.join(colored_tags)}")
# Out:
# Libro 1:
# Título: Discernment: Reading the Signs of Daily Life
# Etiquetas reales: ['catholic', 'spirituality', 'theology']
# Etiquetas predichas: ['catholic', 'theology']
# Comparación coloreada: catholic, spirituality, theology
#
# Libro 2:
# Título: Envoy for Christ: 25 Years as a Catholic Apologist
# Etiquetas reales: []
# Etiquetas predichas: ['catholic', 'christ', 'conversions', 'devotional', 'prayer']
# Comparación coloreada:
#
# Libro 3:
# Título: The Resurrection: Experience Life in the Risen Christ
# Etiquetas reales: ['catholic', 'christ', 'lent', 'resurrection', 'testimonies']
# Etiquetas predichas: ['catholic', 'spirituality', 'theology']
# Comparación coloreada: catholic, christ, lent, resurrection, testimonies
#
# Libro 4:
# Título: The Dogma of Purgatory
# Etiquetas reales: ['biography', 'catholic', 'church-history', 'dogmas', 'faith', 'illustrated', 'nonfiction', 'purgatory', 'religion', 'saints', 'sobrenatural', 'spirituality', 'suffering', 'testimonies', 'theology', 'visions']
# Etiquetas predichas: ['dogmas', 'religion', 'theology']
# Comparación coloreada: biography, catholic, church-history, dogmas, faith, illustrated, nonfiction, purgatory, religion, saints, sobrenatural, spirituality, suffering, testimonies, theology, visions
#
# Libro 5:
# Título: Sommes Nous seuls dans L'univers ?
# Etiquetas reales: ['astronomy', 'ufo']
# Etiquetas predichas: ['astronomy', 'science', 'ufo']
# Comparación coloreada: astronomy, ufo
#
# Libro 6:
# Título: Seis sombreros para pensar: El bestseller mundial revisado y actualizado (Biblioteca Edward De Bono) (Spanish Edition)
# Etiquetas reales: ['bestseller', 'nonfiction', 'psichology', 'selfhelp']
# Etiquetas predichas: ['philosophy', 'psichology', 'science']
# Comparación coloreada: bestseller, nonfiction, psichology, selfhelp
#
# Libro 7:
# Título: Quetzalcoatl's Zahir (The Sleuths of the Spanish Transition, #1)
# Etiquetas reales: ['catholic', 'emotional-relationships', 'fiction', 'love', 'marriage', 'mistery', 'romance']
# Etiquetas predichas: ['fiction']
# Comparación coloreada: catholic, emotional-relationships, fiction, love, marriage, mistery, romance
#
# Libro 8:
# Título: Santa Catalina de Siena
# Etiquetas reales: ['biography', 'catholic', 'classics', 'faith', 'history', 'italy', 'medieval', 'nonfiction', 'rating-top', 'religion', 'saints', 'women']
# Etiquetas predichas: ['catholic', 'theology']
# Comparación coloreada: biography, catholic, classics, faith, history, italy, medieval, nonfiction, rating-top, religion, saints, women
#
# Libro 9:
# Título: Rose Book of Bible Charts, Maps, and Time Lines
# Etiquetas reales: ['bible', 'christianity', 'church-history', 'historical', 'history', 'illustrated', 'israel', 'judaism', 'maps', 'nonfiction', 'religion', 'spirituality']
# Etiquetas predichas: ['bible', 'christ', 'christianity']
# Comparación coloreada: bible, christianity, church-history, historical, history, illustrated, israel, judaism, maps, nonfiction, religion, spirituality
#
# Libro 10:
# Título: El cristiano ateo
# Etiquetas reales: ['christianity', 'devotional', 'faith', 'lifestyle', 'nonfiction', 'religion', 'spirituality', 'theology']
# Etiquetas predichas: ['christianity', 'testimonies', 'theology']
# Comparación coloreada: christianity, devotional, faith, lifestyle, nonfiction, religion, spirituality, theology
#
# Libro 11:
# Título: El Viaje De Jonás
# Etiquetas reales: ['fun', 'humor', 'irony', 'jonah', 'prophets', 'travel']
# Etiquetas predichas: ['fiction', 'travel']
# Comparación coloreada: fun, humor, irony, jonah, prophets, travel
#
# Libro 12:
# Título: La leyenda dorada
# Etiquetas reales: ['biography', 'catholic']
# Etiquetas predichas: ['catholic']
# Comparación coloreada: biography, catholic
#
# Libro 13:
# Título: El arte de tener razón
# Etiquetas reales: ['art-of', 'communication', 'debates', 'essays', 'germany', 'nonfiction', 'philosophy', 'politics', 'selfhelp']
# Etiquetas predichas: ['philosophy', 'psichology']
# Comparación coloreada: art-of, communication, debates, essays, germany, nonfiction, philosophy, politics, selfhelp
#
# Libro 14:
# Título: Comprender las Escrituras: Curso completo para el estudio de la Biblia (The Didache Series)
# Etiquetas reales: ['bible']
# Etiquetas predichas: ['bible', 'catholic', 'christ', 'new-testament', 'theology']
# Comparación coloreada: bible
#
# Libro 15:
# Título: The Political Economy of Distributism: Property, Liberty, and the Common Good (Thomistic Ressourcement Series)
# Etiquetas reales: ['capitalism', 'catholic', 'church-history', 'communism', 'economy', 'freedom', 'humanism', 'philosophy', 'politics', 'popes', 'socialism', 'society', 'sociology']
# Etiquetas predichas: ['catholic', 'nonfiction', 'politics', 'religion', 'theology']
# Comparación coloreada: capitalism, catholic, church-history, communism, economy, freedom, humanism, philosophy, politics, popes, socialism, society, sociology
#
# Libro 16:
# Título: The Archaeology of the Bible
# Etiquetas reales: ['archaeology', 'old-testament']
# Etiquetas predichas: ['bible', 'christianity', 'history']
# Comparación coloreada: archaeology, old-testament
#
# Libro 17:
# Título: Into Your Hands, Father: Abandoning Ourselves to the God Who Loves Us
# Etiquetas reales: ['abandonment-in-god', 'catholic', 'christ', 'nonfiction', 'spirituality']
# Etiquetas predichas: ['catholic', 'devotional', 'nonfiction', 'spirituality', 'theology']
# Comparación coloreada: abandonment-in-god, catholic, christ, nonfiction, spirituality
#
# Libro 18:
# Título: My Russian Way: a spiritual autobiography
# Etiquetas reales: ['biography', 'france', 'illustrated', 'miex', 'orthodox-christians', 'russia', 'spirituality']
# Etiquetas predichas: ['catholic', 'classics', 'communism', 'conversions', 'memoir', 'miex', 'nonfiction', 'orthodox-christians', 'russia', 'testimonies']
# Comparación coloreada: biography, france, illustrated, miex, orthodox-christians, russia, spirituality
#
# Libro 19:
# Título: Hispanic Anthology
# Etiquetas reales: ['poetry']
# Etiquetas predichas: ['apparitions', 'catholic', 'history']
# Comparación coloreada: poetry
#
# Libro 20:
# Título: The Papalagi
# Etiquetas reales: ['asia', 'not-available-on-kindle', 'travel']
# Etiquetas predichas: ['catholic', 'fiction']
# Comparación coloreada: asia, not-available-on-kindle, travel
#
# Libro 21:
# Título: The Mystery of Predestination: According to Scripture, the Church and St. Thomas Aquinas
# Etiquetas reales: ['catholic', 'dogmas', 'predestination', 'religion', 'theology']
# Etiquetas predichas: ['catholic', 'faith', 'theology']
# Comparación coloreada: catholic, dogmas, predestination, religion, theology
#
# Libro 22:
# Título: Cómo sobrevivir intelectualmente al siglo XXI
# Etiquetas reales: ['catholic']
# Etiquetas predichas: ['catholic']
# Comparación coloreada: catholic
#
# Libro 23:
# Título: Imitacion de Cristo
# Etiquetas reales: ['catholic', 'christ', 'classics', 'daily-chapter-reading', 'devotional', 'dialogues-with-christ', 'faith', 'favorites', 'mortification', 'philosophy', 'spirituality', 'theology']
# Etiquetas predichas: ['catholic', 'devotional', 'spirituality', 'theology']
# Comparación coloreada: catholic, christ, classics, daily-chapter-reading, devotional, dialogues-with-christ, faith, favorites, mortification, philosophy, spirituality, theology
#
# Libro 24:
# Título: Sobrevivir para contarlo
# Etiquetas reales: ['africa', 'biography', 'catholic', 'church-history', 'history', 'martyrdom', 'memoir', 'nonfiction']
# Etiquetas predichas: []
# Comparación coloreada: africa, biography, catholic, church-history, history, martyrdom, memoir, nonfiction
#
# Libro 25:
# Título: Meditations on Stations of the Cross
# Etiquetas reales: ['catholic', 'christ', 'classics', 'cross', 'illustrated', 'lent', 'meditations', 'passion-of-christ', 'rating-top', 'redemption', 'stations-of-the-cross', 'suffering', 'way-of-the-cross']
# Etiquetas predichas: ['catholic', 'christ', 'devotional', 'lent', 'poetry', 'prayer', 'spirituality']
# Comparación coloreada: catholic, christ, classics, cross, illustrated, lent, meditations, passion-of-christ, rating-top, redemption, stations-of-the-cross, suffering, way-of-the-cross
#
# Libro 26:
# Título: Praying the Rosary Step-by-Step
# Etiquetas reales: ['catholic', 'prayer', 'virgin-mary']
# Etiquetas predichas: ['catholic', 'devotional', 'meditations', 'prayer', 'spirituality', 'virgin-mary']
# Comparación coloreada: catholic, prayer, virgin-mary
#
# Libro 27:
# Título: Mao: A Life
# Etiquetas reales: ['biography', 'communism']
# Etiquetas predichas: ['classics', 'communism']
# Comparación coloreada: biography, communism
#
# Libro 28:
# Título: El libro de los mártires
# Etiquetas reales: ['biography', 'christianity', 'church-history', 'classics', 'faith', 'history', 'hope', 'martyrdom', 'saints', 'suffering', 'theology']
# Etiquetas predichas: ['catholic', 'history', 'religion']
# Comparación coloreada: biography, christianity, church-history, classics, faith, history, hope, martyrdom, saints, suffering, theology
#
# Libro 29:
# Título: The Arrogant Years: One Girl's Search for Her Lost Youth, from Cairo to Brooklyn
# Etiquetas reales: ['africa', 'biography', 'history', 'islamism', 'israel', 'judaism', 'lifestyle', 'memoir', 'nonfiction', 'politics', 'suffering', 'usa', 'women']
# Etiquetas predichas: ['biography', 'fiction', 'memoir', 'testimonies', 'women']
# Comparación coloreada: africa, biography, history, islamism, israel, judaism, lifestyle, memoir, nonfiction, politics, suffering, usa, women
#
# Libro 30:
# Título: Historia de un alma
# Etiquetas reales: ['biography']
# Etiquetas predichas: ['biography', 'catholic', 'nonfiction', 'nuns', 'spirituality', 'theology']
# Comparación coloreada: biography
#
# Libro 31:
# Título: On the Third Part of the Secret of Fatima
# Etiquetas reales: ['apparitions', 'mistery', 'profecies', 'virgin-mary']
# Etiquetas predichas: ['apparitions', 'catholic', 'church-history', 'france', 'virgin-mary']
# Comparación coloreada: apparitions, mistery, profecies, virgin-mary
#
# Libro 32:
# Título: To Autolychus
# Etiquetas reales: ['christianity', 'church-history']
# Etiquetas predichas: []
# Comparación coloreada: christianity, church-history
#
# Libro 33:
# Título: Del sentimiento trágico de la vida
# Etiquetas reales: ['atheism', 'death', 'existence-of-god', 'faith', 'philosophy']
# Etiquetas predichas: ['catholic', 'classics', 'philosophy', 'psichology', 'suffering', 'theology']
# Comparación coloreada: atheism, death, existence-of-god, faith, philosophy
#
# Libro 34:
# Título: On Which Side of the Road Do the Flowers Grow?
# Etiquetas reales: ['agriculture', 'allegories', 'beauty', 'biography', 'botany', 'christianity', 'faith', 'humor', 'inspirational', 'miex', 'nonfiction', 'priests', 'spirituality', 'testimonies', 'theology']
# Etiquetas predichas: ['catholic', 'devotional']
# Comparación coloreada: agriculture, allegories, beauty, biography, botany, christianity, faith, humor, inspirational, miex, nonfiction, priests, spirituality, testimonies, theology
#
# Libro 35:
# Título: The Monks of Tibhirine: Faith, Love, and Terror in Algeria
# Etiquetas reales: ['africa', 'biography', 'church-history', 'faith', 'france', 'history', 'islamism', 'love', 'martyrdom', 'monks', 'nonfiction', 'religion', 'suffering']
# Etiquetas predichas: ['history']
# Comparación coloreada: africa, biography, church-history, faith, france, history, islamism, love, martyrdom, monks, nonfiction, religion, suffering
#
# Libro 36:
# Título: Mexican Martyrdom: Firsthand Accounts of the Religious Persecution in Mexico 1926-1935
# Etiquetas reales: ['america', 'atheism', 'catholic', 'church-history', 'communism', 'hispanic-heritage', 'martyrdom', 'mexico', 'persecutions']
# Etiquetas predichas: ['biography', 'catholic', 'martyrdom', 'testimonies']
# Comparación coloreada: america, atheism, catholic, church-history, communism, hispanic-heritage, martyrdom, mexico, persecutions
#
# Libro 37:
# Título: Preparacion para la muerte: Clasicos Catolicos
# Etiquetas reales: ['catholic', 'classics', 'death', 'meditations', 'mortification', 'nonfiction', 'prayer', 'spirituality', 'suffering', 'theology']
# Etiquetas predichas: ['catholic', 'devotional', 'prayer', 'spirituality']
# Comparación coloreada: catholic, classics, death, meditations, mortification, nonfiction, prayer, spirituality, suffering, theology
#
# Libro 38:
# Título: La devoción al Sagrado Corazón de Jesús: P. Jean Croiset. Director espiritual de Sta. Margarita María de Alacoque
# Etiquetas reales: ['catholic']
# Etiquetas predichas: ['catholic', 'devotional', 'nonfiction', 'spirituality', 'theology']
# Comparación coloreada: catholic
#
# Libro 39:
# Título: We Three Kings
# Etiquetas reales: ['children', 'christianity', 'christmas', 'illustrated', 'music']
# Etiquetas predichas: ['catholic', 'christ', 'christianity', 'church-history', 'fiction', 'nonfiction', 'religion', 'theology']
# Comparación coloreada: children, christianity, christmas, illustrated, music
#
# Libro 40:
# Título: Darwin Devolves : The New Science About DNA That Challenges Evolution
# Etiquetas reales: ['evolution', 'genesis', 'nonfiction', 'religion', 'science']
# Etiquetas predichas: ['philosophy', 'science']
# Comparación coloreada: evolution, genesis, nonfiction, religion, science
#
# Libro 41:
# Título: El leon, la bruja y el ropero
# Etiquetas reales: ['adolescence', 'children', 'christianity', 'classics', 'fantasy', 'fiction', 'illustrated', 'series']
# Etiquetas predichas: ['children', 'fiction']
# Comparación coloreada: adolescence, children, christianity, classics, fantasy, fiction, illustrated, series
#
# Libro 42:
# Título: Desde que no estás (HQN nº 75) (Spanish Edition)
# Etiquetas reales: ['miex', 'women']
# Etiquetas predichas: ['biography', 'faith', 'fiction', 'love', 'women']
# Comparación coloreada: miex, women
#
# Libro 43:
# Título: Las arenas de Marte
# Etiquetas reales: ['astronomy', 'classics', 'fiction', 'novels', 'space']
# Etiquetas predichas: ['fiction', 'nonfiction']
# Comparación coloreada: astronomy, classics, fiction, novels, space
#
# Libro 44:
# Título: This Explains Everything: Deep, Beautiful, and Elegant Theories of How the World Works
# Etiquetas reales: []
# Etiquetas predichas: ['science']
# Comparación coloreada:
#
# Libro 45:
# Título: Into the Silence: The Great War, Mallory, and the Conquest of Everest
# Etiquetas reales: ['adventures', 'asia', 'biography', 'himalayas', 'history', 'mountaineering', 'nonfiction', 'travel', 'war']
# Etiquetas predichas: ['church-history', 'history', 'mountaineering', 'nonfiction']
# Comparación coloreada: adventures, asia, biography, himalayas, history, mountaineering, nonfiction, travel, war
#
# Libro 46:
# Título: Jesus, Interrupted: Revealing the Hidden Contradictions in the Bible (and Why We Don't Know About Them)
# Etiquetas reales: ['agnosticism', 'atheism', 'christ', 'new-testament', 'protestantism', 'theology']
# Etiquetas predichas: ['bible', 'christ', 'new-testament', 'theology']
# Comparación coloreada: agnosticism, atheism, christ, new-testament, protestantism, theology
#
# Libro 47:
# Título: Mysterium Paschale: The Mystery of Easter
# Etiquetas reales: ['catholic', 'lent']
# Etiquetas predichas: ['catholic', 'theology']
# Comparación coloreada: catholic, lent
#
# Libro 48:
# Título: Roses in the Snow: A Tale of Saint Elizabeth of Hungary
# Etiquetas reales: ['biography', 'catholic', 'charity', 'children', 'church-history', 'fables', 'history', 'holiness', 'illustrated', 'miex', 'not-available-on-kindle', 'saints', 'short-stories', 'women']
# Etiquetas predichas: ['biography', 'catholic', 'church-history', 'historical', 'nonfiction', 'nuns', 'poetry', 'women']
# Comparación coloreada: biography, catholic, charity, children, church-history, fables, history, holiness, illustrated, miex, not-available-on-kindle, saints, short-stories, women
#
# Libro 49:
# Título: Thoughts of the Curé of Ars
# Etiquetas reales: ['catholic', 'devotional']
# Etiquetas predichas: ['catholic', 'suffering']
# Comparación coloreada: catholic, devotional
#
# Libro 50:
# Título: Liturgia De Las Horas IV (Rite/Ritual Books) (Volume 4) (Spanish Edition)
# Etiquetas reales: ['catholic']
# Etiquetas predichas: []
# Comparación coloreada: catholic
#
# Libro 51:
# Título: Desolacion
# Etiquetas reales: ['america', 'award-winning', 'christ', 'lent', 'poetry', 'women']
# Etiquetas predichas: ['biography', 'catholic', 'fiction', 'women']
# Comparación coloreada: america, award-winning, christ, lent, poetry, women
#
# Libro 52:
# Título: Where Love is, There God is Also
# Etiquetas reales: ['allegories', 'christianity', 'classics', 'fiction', 'love', 'miex', 'orthodox-christians', 'religion', 'russia']
# Etiquetas predichas: ['catholic']
# Comparación coloreada: allegories, christianity, classics, fiction, love, miex, orthodox-christians, religion, russia
#
# Libro 53:
# Título: The Sign of Jonas
# Etiquetas reales: ['biography', 'catholic', 'jonah', 'monks', 'nonfiction', 'prophets', 'religion', 'spirituality', 'theology']
# Etiquetas predichas: ['catholic', 'classics', 'fiction', 'illustrated']
# Comparación coloreada: biography, catholic, jonah, monks, nonfiction, prophets, religion, spirituality, theology
#
# Libro 54:
# Título: Answer to Job: (From Vol. 11 of the Collected Works of C. G. Jung) (Jung Extracts)
# Etiquetas reales: ['christianity', 'faith', 'job', 'philosophy', 'psichology', 'quarantine', 'religion', 'spirituality', 'theology']
# Etiquetas predichas: []
# Comparación coloreada: christianity, faith, job, philosophy, psichology, quarantine, religion, spirituality, theology
#
# Libro 55:
# Título: O Trabalho Intelectual: Conselhos para os que estudam e para os que escrevem
# Etiquetas reales: ['education', 'france', 'nonfiction', 'philosophy', 'writing']
# Etiquetas predichas: ['catholic', 'philosophy', 'psichology', 'selfhelp']
# Comparación coloreada: education, france, nonfiction, philosophy, writing
#
# Libro 56:
# Título: La Rueda del Tiempo
# Etiquetas reales: ['newage']
# Etiquetas predichas: ['newage']
# Comparación coloreada: newage
#
# Libro 57:
# Título: Attitude Is Everything: Change Your Attitude... Change Your Life!
# Etiquetas reales: ['business', 'leadership', 'psichology', 'selfhelp']
# Etiquetas predichas: ['lifestyle', 'psichology', 'selfhelp']
# Comparación coloreada: business, leadership, psichology, selfhelp
#
# Libro 58:
# Título: Praying the Rosary for Inner Healing
# Etiquetas reales: ['catholic', 'health', 'prayer', 'virgin-mary']
# Etiquetas predichas: ['catholic', 'devotional', 'faith', 'meditations', 'prayer', 'spirituality', 'virgin-mary']
# Comparación coloreada: catholic, health, prayer, virgin-mary
#
# Libro 59:
# Título: Color Atlas of Pharmacology
# Etiquetas reales: ['science']
# Etiquetas predichas: ['illustrated', 'nonfiction', 'science']
# Comparación coloreada: science
#
# Libro 60:
# Título: Just William
# Etiquetas reales: ['adolescence', 'adventures', 'audiobooks', 'children', 'classics', 'fiction', 'humor', 'light-reading', 'uk']
# Etiquetas predichas: ['catholic', 'children', 'fiction', 'spirituality', 'theology']
# Comparación coloreada: adolescence, adventures, audiobooks, children, classics, fiction, humor, light-reading, uk
#
# Libro 61:
# Título: Cuando nos prohibieron ser mujeres ...y os persiguieron por ser hombres: Para entender cómo nos afecta la ideología de género
# Etiquetas reales: ['communism', 'decline', 'education', 'gender-ideology', 'identity', 'ideologies', 'indoctrination', 'left-wing', 'manipulation', 'masculinity', 'politics', 'sexuality', 'socialism', 'society', 'sociology', 'women']
# Etiquetas predichas: ['philosophy', 'psichology', 'sexuality']
# Comparación coloreada: communism, decline, education, gender-ideology, identity, ideologies, indoctrination, left-wing, manipulation, masculinity, politics, sexuality, socialism, society, sociology, women
#
# Libro 62:
# Título: An Examination of the Testimony of the Four Evangelists, by the Rules of Evidence administered in Courts of Justice
# Etiquetas reales: ['christianity', 'church-history', 'gospels', 'history', 'justice', 'law', 'lent', 'leyes', 'new-testament', 'nonfiction', 'passion-of-christ', 'religion', 'research', 'resurrection', 'silence', 'singlehood', 'testimonies', 'theology']
# Etiquetas predichas: ['catholic']
# Comparación coloreada: christianity, church-history, gospels, history, justice, law, lent, leyes, new-testament, nonfiction, passion-of-christ, religion, research, resurrection, silence, singlehood, testimonies, theology
#
# Libro 63:
# Título: Mero cristianismo
# Etiquetas reales: ['apologetics', 'catholic', 'classics', 'faith', 'favorites', 'holy-spirit', 'holy-trinity', 'hope', 'ladder', 'love', 'morality', 'nonfiction', 'philosophy', 'religion', 'theology', 'virtues']
# Etiquetas predichas: ['catholic', 'christianity', 'faith', 'philosophy', 'theology']
# Comparación coloreada: apologetics, catholic, classics, faith, favorites, holy-spirit, holy-trinity, hope, ladder, love, morality, nonfiction, philosophy, religion, theology, virtues
#
# Libro 64:
# Título: El Hermano de Asis (San Francisco de Asis)
# Etiquetas reales: ['biography', 'catholic', 'nonfiction', 'religion', 'saint-francis-of-assisi', 'saints', 'theraphy']
# Etiquetas predichas: ['biography', 'catholic', 'devotional', 'saints', 'testimonies', 'theology']
# Comparación coloreada: biography, catholic, nonfiction, religion, saint-francis-of-assisi, saints, theraphy
#
# Libro 65:
# Título: La Messa cattolica: Passi per ripristinare la centralità di Dio nella liturgia (Liturgia e musica sacra Vol. 18) (Italian Edition)
# Etiquetas reales: ['catholic', 'devotional', 'eucharist', 'prayer', 'worship']
# Etiquetas predichas: ['catholic', 'nonfiction', 'prayer', 'spirituality', 'theology']
# Comparación coloreada: catholic, devotional, eucharist, prayer, worship
#
# Libro 66:
# Título: Encuentros: la historia de los ovni en España
# Etiquetas reales: ['ufo']
# Etiquetas predichas: []
# Comparación coloreada: ufo
#
# Libro 67:
# Título: The Tree of Life
# Etiquetas reales: ['film', 'love', 'philosophy', 'spirituality']
# Etiquetas predichas: ['classics', 'fiction']
# Comparación coloreada: film, love, philosophy, spirituality
#
# Libro 68:
# Título: The Myth of the Andalusian Paradise: Muslims, Christians, and Jews under Islamic Rule in Medieval Spain
# Etiquetas reales: ['history', 'islamism']
# Etiquetas predichas: ['catholic', 'fiction', 'history', 'religion']
# Comparación coloreada: history, islamism
#
# Libro 69:
# Título: The Truth about Saint Joseph: Encountering the Most Hidden of Saints
# Etiquetas reales: ['biography', 'catholic']
# Etiquetas predichas: ['biography', 'catholic', 'christ', 'israel', 'prayer']
# Comparación coloreada: biography, catholic
#
# Libro 70:
# Título: La cabaña
# Etiquetas reales: ['allegories', 'christianity', 'fiction', 'holy-spirit', 'holy-trinity']
# Etiquetas predichas: ['fiction', 'love', 'miex']
# Comparación coloreada: allegories, christianity, fiction, holy-spirit, holy-trinity
#
# Libro 71:
# Título: Crosses, Sunsets & Sinners: A Brother And Sisters Medjugorje Journey
# Etiquetas reales: []
# Etiquetas predichas: ['catholic', 'religion', 'testimonies', 'virgin-mary']
# Comparación coloreada:
#
# Libro 72:
# Título: UFOs: Generals, Pilots and Government Officials Go on the Record
# Etiquetas reales: ['ufo']
# Etiquetas predichas: ['ufo']
# Comparación coloreada: ufo
#
# Libro 73:
# Título: Silencio (Narrativas Históricas)
# Etiquetas reales: ['catholic', 'classics', 'fiction', 'japan', 'silence']
# Etiquetas predichas: ['classics']
# Comparación coloreada: catholic, classics, fiction, japan, silence
#
# Libro 74:
# Título: Padres fuertes, hijas felices
# Etiquetas reales: ['marriage', 'psichology', 'women']
# Etiquetas predichas: ['psichology', 'selfhelp']
# Comparación coloreada: marriage, psichology, women
#
# Libro 75:
# Título: Total Consecration Through the Mysteries of the Rosary
# Etiquetas reales: ['catholic', 'prayer', 'religion', 'spirituality', 'virgin-mary']
# Etiquetas predichas: ['catholic', 'devotional', 'faith', 'meditations', 'prayer', 'spirituality', 'virgin-mary']
# Comparación coloreada: catholic, prayer, religion, spirituality, virgin-mary
#
# Libro 76:
# Título: Necessary Losses: The Loves, Illusions, Dependencies, and Impossible Expectations That All of Us Have to Give Up in Order to Grow
# Etiquetas reales: ['emotional-relationships', 'essays', 'grief', 'loneliness', 'loss', 'love', 'marriage', 'mental-health', 'miex', 'nonfiction', 'psichology', 'restart', 'selfhelp', 'separation', 'spirituality', 'suffering']
# Etiquetas predichas: ['restart', 'suffering']
# Comparación coloreada: emotional-relationships, essays, grief, loneliness, loss, love, marriage, mental-health, miex, nonfiction, psichology, restart, selfhelp, separation, spirituality, suffering
#
# Libro 77:
# Título: The Insect Folk : complete with original Illustration
# Etiquetas reales: ['america', 'children', 'education', 'entomology', 'illustrated', 'nature', 'nonfiction', 'usa']
# Etiquetas predichas: ['christianity', 'nonfiction']
# Comparación coloreada: america, children, education, entomology, illustrated, nature, nonfiction, usa
#
# Libro 78:
# Título: The Evidence of Things Not Seen: A Mountaineer's Tale
# Etiquetas reales: ['adventures', 'asia', 'himalayas', 'memoir', 'mountaineering', 'uk']
# Etiquetas predichas: ['biography', 'christianity', 'mountaineering']
# Comparación coloreada: adventures, asia, himalayas, memoir, mountaineering, uk
#
# Libro 79:
# Título: Design Patterns For Dummies
# Etiquetas reales: ['programming']
# Etiquetas predichas: ['nonfiction', 'programming', 'science']
# Comparación coloreada: programming
#
# Libro 80:
# Título: Cuatro sermones sobre el Anticristo: La idea patrística del Anticristo en cuatro sermones (Religión)
# Etiquetas reales: ['catholic', 'new-testament']
# Etiquetas predichas: ['catholic', 'theology']
# Comparación coloreada: catholic, new-testament
#
# Libro 81:
# Título: The Eucharist Foretold: The Lost Prophecy of Malachi
# Etiquetas reales: ['bible', 'catholic', 'church-history', 'eucharist', 'identity', 'israel', 'old-testament', 'patristics', 'profecies', 'prophets']
# Etiquetas predichas: ['christianity', 'orthodox-christians', 'religion', 'theology']
# Comparación coloreada: bible, catholic, church-history, eucharist, identity, israel, old-testament, patristics, profecies, prophets
#
# Libro 82:
# Título: Poems Every Catholic Should Know
# Etiquetas reales: ['catholic', 'church-history', 'poetry', 'saints']
# Etiquetas predichas: ['catholic', 'christianity', 'poetry']
# Comparación coloreada: catholic, church-history, poetry, saints
#
# Libro 83:
# Título: St. Bernadette Soubirous: 1844-1879
# Etiquetas reales: ['apparitions', 'beatific-visions', 'biography', 'catholic', 'church-history', 'faith', 'france', 'historical', 'lourdes', 'miracles', 'nonfiction', 'nuns', 'spirituality', 'virgin-mary']
# Etiquetas predichas: ['apparitions', 'beatific-visions', 'biography', 'catholic', 'classics', 'france', 'lourdes', 'nuns', 'spirituality', 'virgin-mary']
# Comparación coloreada: apparitions, beatific-visions, biography, catholic, church-history, faith, france, historical, lourdes, miracles, nonfiction, nuns, spirituality, virgin-mary
#
# Libro 84:
# Título: The Passionate Programmer: Creating a Remarkable Career in Software Development
# Etiquetas reales: ['programming']
# Etiquetas predichas: ['programming']
# Comparación coloreada: programming
#
# Libro 85:
# Título: The Beauty of Faith: Using Christian Art To Spread Good News
# Etiquetas reales: ['art', 'catholic']
# Etiquetas predichas: ['art', 'catholic', 'illustrated']
# Comparación coloreada: art, catholic
#
# Libro 86:
# Título: Person and the Common Good
# Etiquetas reales: ['catholic', 'philosophy', 'politics']
# Etiquetas predichas: ['emotional-relationships', 'philosophy']
# Comparación coloreada: catholic, philosophy, politics
#
# Libro 87:
# Título: El segundo anillo del poder
# Etiquetas reales: ['newage']
# Etiquetas predichas: []
# Comparación coloreada: newage
#
# Libro 88:
# Título: Mind & Cosmos: Why the Materialist Neo-Darwinian Conception of Nature is Almost Certainly False
# Etiquetas reales: []
# Etiquetas predichas: ['philosophy', 'science']
# Comparación coloreada:
#
# Libro 89:
# Título: Paths of Glory
# Etiquetas reales: ['adventures', 'audiobooks', 'drama', 'fiction', 'historical-fiction', 'mistery', 'mountaineering', 'thriller']
# Etiquetas predichas: []
# Comparación coloreada: adventures, audiobooks, drama, fiction, historical-fiction, mistery, mountaineering, thriller
#
# Libro 90:
# Título: David y Goliat. Desvalidos, inadaptados y el arte de luchar contra gigantes
# Etiquetas reales: ['art-of', 'audiobooks', 'business', 'history', 'nonfiction', 'philosophy', 'psichology', 'science', 'selfhelp', 'sociology', 'sports']
# Etiquetas predichas: []
# Comparación coloreada: art-of, audiobooks, business, history, nonfiction, philosophy, psichology, science, selfhelp, sociology, sports
#
# Libro 91:
# Título: Cartas a un Joven Poeta
# Etiquetas reales: ['catholic', 'poetry']
# Etiquetas predichas: ['catholic', 'philosophy']
# Comparación coloreada: catholic, poetry
#
# Libro 92:
# Título: Pacto matrimonial: Perspectiva temporal y eterna
# Etiquetas reales: ['bible', 'christianity', 'courtship', 'emotional-relationships', 'love', 'marriage', 'nonfiction', 'parables']
# Etiquetas predichas: ['devotional', 'marriage', 'theology']
# Comparación coloreada: bible, christianity, courtship, emotional-relationships, love, marriage, nonfiction, parables
#
# Libro 93:
# Título: Rebelión en la granja
# Etiquetas reales: ['agriculture', 'classics', 'communism', 'fiction', 'parables', 'politics', 'russia', 'short-stories']
# Etiquetas predichas: ['catholic', 'classics', 'communism', 'fiction', 'politics']
# Comparación coloreada: agriculture, classics, communism, fiction, parables, politics, russia, short-stories
#
# Libro 94:
# Título: A Prayer Journal
# Etiquetas reales: ['catholic', 'prayer']
# Etiquetas predichas: ['catholic', 'poetry', 'spirituality']
# Comparación coloreada: catholic, prayer
#
# Libro 95:
# Título: Quo Vadis?: Una historia de los tiempos de Nerón
# Etiquetas reales: ['classics', 'fiction', 'film', 'romance']
# Etiquetas predichas: ['classics', 'fiction']
# Comparación coloreada: classics, fiction, film, romance
#
# Libro 96:
# Título: How To Control Your Anxiety Before It Controls You
# Etiquetas reales: ['anxiety', 'mental-health', 'miex', 'nonfiction', 'psichology', 'selfhelp']
# Etiquetas predichas: ['anxiety', 'mental-health', 'miex', 'nonfiction', 'psichology', 'selfhelp']
# Comparación coloreada: anxiety, mental-health, miex, nonfiction, psichology, selfhelp
#
# Libro 97:
# Título: El peregrino ruso
# Etiquetas reales: ['christianity', 'classics', 'ladder', 'light-reading', 'miex', 'prayer', 'religion', 'russia', 'spirituality', 'theology']
# Etiquetas predichas: ['catholic', 'classics', 'miex', 'nonfiction', 'orthodox-christians', 'prayer', 'russia']
# Comparación coloreada: christianity, classics, ladder, light-reading, miex, prayer, religion, russia, spirituality, theology
#
# Libro 98:
# Título: Imitación y experiencia (Tetralogía de la ejemplaridad, #1)
# Etiquetas reales: ['philosophy']
# Etiquetas predichas: ['classics', 'history', 'philosophy', 'psichology']
# Comparación coloreada: philosophy
#
# Libro 99:
# Título: Looking for the King (Inklings, #1)
# Etiquetas reales: []
# Etiquetas predichas: ['biography', 'catholic', 'christianity', 'fiction', 'philosophy', 'testimonies', 'uk']
# Comparación coloreada:
#
# Libro 100:
# Título: The Big Lie
# Etiquetas reales: []
# Etiquetas predichas: ['communism', 'politics']
# Comparación coloreada:
#
# Libro 101:
# Título: Dificultades en la oración mental
# Etiquetas reales: ['catholic', 'devotional', 'prayer', 'spirituality']
# Etiquetas predichas: ['catholic', 'devotional', 'prayer', 'spirituality', 'theology']
# Comparación coloreada: catholic, devotional, prayer, spirituality
#
# Libro 102:
# Título: Dyatlov Pass
# Etiquetas reales: ['fiction', 'historical', 'horror', 'mistery', 'paranormal', 'russia', 'science-fiction', 'ufo']
# Etiquetas predichas: []
# Comparación coloreada: fiction, historical, horror, mistery, paranormal, russia, science-fiction, ufo
#
# Libro 103:
# Título: Conversation With Christ
# Etiquetas reales: ['asceticism', 'catholic', 'dialogues-with-christ', 'holiness', 'misticism', 'nonfiction', 'nuns', 'prayer', 'saint-teresa-of-jesus', 'saints', 'spiritual-warfare', 'spirituality']
# Etiquetas predichas: ['catholic', 'devotional', 'nonfiction', 'nuns', 'prayer', 'spirituality', 'theology']
# Comparación coloreada: asceticism, catholic, dialogues-with-christ, holiness, misticism, nonfiction, nuns, prayer, saint-teresa-of-jesus, saints, spiritual-warfare, spirituality
#
# Libro 104:
# Título: Padres e hijos
# Etiquetas reales: ['classics', 'family', 'fatherhood', 'fiction', 'novels', 'russia']
# Etiquetas predichas: ['catholic', 'communism', 'fiction', 'nonfiction', 'russia', 'spirituality']
# Comparación coloreada: classics, family, fatherhood, fiction, novels, russia
#
# Libro 105:
# Título: Obras Completas de San Juan de la Cruz
# Etiquetas reales: ['asceticism', 'biography', 'catholic', 'classics', 'dialogues-with-christ', 'misticism', 'monks', 'nonfiction', 'poetry', 'saints', 'spain', 'spirituality', 'theology']
# Etiquetas predichas: ['catholic', 'classics']
# Comparación coloreada: asceticism, biography, catholic, classics, dialogues-with-christ, misticism, monks, nonfiction, poetry, saints, spain, spirituality, theology
#
# Libro 106:
# Título: Under an orange sky (Solar System, #1)
# Etiquetas reales: ['fiction', 'silence']
# Etiquetas predichas: ['ufo']
# Comparación coloreada: fiction, silence
#
# Libro 107:
# Título: Fascinating Womanhood: Vintage Edition
# Etiquetas reales: ['family', 'feminism', 'marriage', 'motherhood', 'relationships', 'tradwife', 'tradwives', 'women']
# Etiquetas predichas: ['nonfiction', 'women']
# Comparación coloreada: family, feminism, marriage, motherhood, relationships, tradwife, tradwives, women
#
# Libro 108:
# Título: The Life of St. Dominic
# Etiquetas reales: ['beatific-visions', 'biography', 'catholic', 'charity', 'church-history', 'dominicans', 'english-language', 'europe', 'fire-on-earth', 'miracles', 'monasteries', 'monks', 'nonfiction', 'prayer', 'preaching', 'rosary', 'saints', 'spain']
# Etiquetas predichas: ['biography', 'catholic', 'christianity', 'religion', 'saints', 'theology']
# Comparación coloreada: beatific-visions, biography, catholic, charity, church-history, dominicans, english-language, europe, fire-on-earth, miracles, monasteries, monks, nonfiction, prayer, preaching, rosary, saints, spain
#
# Libro 109:
# Título: Last Hours on Everest
# Etiquetas reales: ['adventures', 'asia', 'himalayas', 'mountaineering', 'nonfiction']
# Etiquetas predichas: ['christ', 'history', 'lent', 'mountaineering']
# Comparación coloreada: adventures, asia, himalayas, mountaineering, nonfiction
#
# Libro 110:
# Título: Padre Amorth: La mia battaglia con Dio contro Satana
# Etiquetas reales: ['biography', 'demons']
# Etiquetas predichas: ['theology']
# Comparación coloreada: biography, demons
#
# Libro 111:
# Título: How Catholic Art Saved the Faith: The Triumph of Beauty and Truth in Counter-Reformation Art
# Etiquetas reales: ['art', 'catholic', 'church-history', 'dogmas', 'rating-top']
# Etiquetas predichas: ['art', 'catholic', 'theology']
# Comparación coloreada: art, catholic, church-history, dogmas, rating-top
#
# Libro 112:
# Título: 21 Días para tener tu casa en orden: El método de orden que cambiará tu vida
# Etiquetas reales: ['decoration']
# Etiquetas predichas: []
# Comparación coloreada: decoration
#
# Libro 113:
# Título: The Way of Silence: Engaging the Sacred in Daily Life
# Etiquetas reales: ['catholic', 'devotional', 'philosophy', 'silence']
# Etiquetas predichas: ['catholic', 'classics', 'devotional', 'philosophy', 'rating-top', 'silence', 'spirituality', 'theology']
# Comparación coloreada: catholic, devotional, philosophy, silence
#
# Libro 114:
# Título: Conversos, buscadores de Dios: 12 historias de fe de los siglos XX y XXI (Camino de Damasco) (Spanish Edition)
# Etiquetas reales: ['catholic', 'testimonies']
# Etiquetas predichas: ['catholic', 'faith']
# Comparación coloreada: catholic, testimonies
#
# Libro 115:
# Título: A Message of Hope from the Angels
# Etiquetas reales: ['angels']
# Etiquetas predichas: ['christianity', 'spirituality', 'women']
# Comparación coloreada: angels
#
# Libro 116:
# Título: Triunfa con tu libro: Cómo publicar y vender tu libro con éxito (Incluye Acceso GRATIS al Taller Online: Escribir tu Bestseller en 60 días) (Spanish Edition)
# Etiquetas reales: ['writing']
# Etiquetas predichas: []
# Comparación coloreada: writing
#
# Libro 117:
# Título: Star Struck: Seeing the Creator in the Wonders of Our Cosmos
# Etiquetas reales: ['astronomy', 'christianity', 'creation', 'nonfiction', 'science', 'space', 'theology']
# Etiquetas predichas: ['astronomy', 'nonfiction', 'science']
# Comparación coloreada: astronomy, christianity, creation, nonfiction, science, space, theology
#
# Libro 118:
# Título: Celebrate Mass With Your Heart
# Etiquetas reales: ['catholic', 'devotional', 'eucharist', 'franciscans', 'heart', 'love', 'medjugorje', 'monks', 'nonfiction', 'not-available-on-kindle', 'prayer', 'spirituality', 'theology']
# Etiquetas predichas: ['catholic', 'christ', 'devotional', 'religion', 'theology']
# Comparación coloreada: catholic, devotional, eucharist, franciscans, heart, love, medjugorje, monks, nonfiction, not-available-on-kindle, prayer, spirituality, theology
#
# Libro 119:
# Título: When Fiction & Philosophy Meet (Flannery O'Connor)
# Etiquetas reales: ['fiction', 'france', 'literary-criticism', 'nonfiction', 'not-available-on-kindle', 'philosophy', 'religion', 'usa', 'women']
# Etiquetas predichas: ['fiction']
# Comparación coloreada: fiction, france, literary-criticism, nonfiction, not-available-on-kindle, philosophy, religion, usa, women
#
# Libro 120:
# Título: La era del vacío
# Etiquetas reales: ['psichology']
# Etiquetas predichas: ['fiction', 'politics']
# Comparación coloreada: psichology
#
# Libro 121:
# Título: Alfred Hitchcock y los tres Investigadores. Misterio del Diablo Danzante
# Etiquetas reales: ['adolescence', 'children']
# Etiquetas predichas: ['catholic', 'classics', 'fiction']
# Comparación coloreada: adolescence, children
#
# Libro 122:
# Título: Blessed Charles of Austria: A Holy Emperor and His Legacy
# Etiquetas reales: ['biography', 'blessings', 'catholic', 'family', 'history', 'politics', 'war']
# Etiquetas predichas: ['biography', 'catholic', 'saints', 'theology']
# Comparación coloreada: biography, blessings, catholic, family, history, politics, war
#
# Libro 123:
# Título: From Jesus to Christ: The Origins of the New Testament Images of Christ
# Etiquetas reales: ['christ', 'quarantine']
# Etiquetas predichas: ['bible', 'catholic', 'christ', 'christianity', 'church-history', 'israel', 'lent', 'new-testament', 'religion', 'theology']
# Comparación coloreada: christ, quarantine
#
# Libro 124:
# Título: Regla del Gran Padre y Patriarca San Benito: 1850
# Etiquetas reales: ['catholic', 'church-history', 'classics', 'humility', 'monks', 'nonfiction', 'philosophy', 'religion', 'spirituality', 'theology']
# Etiquetas predichas: ['catholic', 'saints']
# Comparación coloreada: catholic, church-history, classics, humility, monks, nonfiction, philosophy, religion, spirituality, theology
#
# Libro 125:
# Título: A Journey with Jonah: The Spirituality of Bewilderment
# Etiquetas reales: ['catholic', 'jonah', 'old-testament', 'prophets', 'spirituality']
# Etiquetas predichas: ['catholic', 'christianity', 'orthodox-christians']
# Comparación coloreada: catholic, jonah, old-testament, prophets, spirituality
#
# Libro 126:
# Título: Escandalosa Misericordia (Latam Edition)
# Etiquetas reales: ['catholic', 'testimonies']
# Etiquetas predichas: ['catholic']
# Comparación coloreada: catholic, testimonies
#
# Libro 127:
# Título: El punto ciego: Psicología del autoengaño
# Etiquetas reales: ['psichology']
# Etiquetas predichas: ['nonfiction', 'psichology', 'selfhelp']
# Comparación coloreada: psichology
#
# Libro 128:
# Título: El último Papa
# Etiquetas reales: ['catholic', 'church', 'church-history', 'communism', 'devil', 'globalism', 'masonry', 'nonfiction', 'popes', 'profecies', 'socialism', 'vatican']
# Etiquetas predichas: ['catholic', 'church-history', 'communism', 'faith', 'theology']
# Comparación coloreada: catholic, church, church-history, communism, devil, globalism, masonry, nonfiction, popes, profecies, socialism, vatican
#
# Libro 129:
# Título: Tratado de la Oración y Meditación
# Etiquetas reales: []
# Etiquetas predichas: ['catholic', 'devotional', 'prayer', 'theology']
# Comparación coloreada:
#
# Libro 130:
# Título: Nazaret (Caballo de Troya, #4)
# Etiquetas reales: ['fiction']
# Etiquetas predichas: ['catholic', 'christ']
# Comparación coloreada: fiction
#
# Libro 131:
# Título: Spiritual Direction: A Guide for Sharing the Father’s Love
# Etiquetas reales: ['catholic', 'devotional', 'prayer', 'psichology']
# Etiquetas predichas: ['catholic', 'devotional', 'miex', 'nonfiction', 'spirituality']
# Comparación coloreada: catholic, devotional, prayer, psichology
#
# Libro 132:
# Título: El combate espiritual
# Etiquetas reales: []
# Etiquetas predichas: ['catholic', 'devotional', 'theology']
# Comparación coloreada:
#
# Libro 133:
# Título: Adam: God's Beloved
# Etiquetas reales: ['ars-moriendi', 'biography', 'catholic', 'death', 'disability', 'faith', 'friendship', 'genesis', 'gospels', 'hope', 'illness', 'memoir', 'nonfiction', 'old-testament', 'overcoming', 'restart', 'selfhelp', 'spirituality', 'suffering', 'testimonies', 'theology']
# Etiquetas predichas: ['biography', 'catholic', 'christianity', 'classics', 'fiction', 'theology']
# Comparación coloreada: ars-moriendi, biography, catholic, death, disability, faith, friendship, genesis, gospels, hope, illness, memoir, nonfiction, old-testament, overcoming, restart, selfhelp, spirituality, suffering, testimonies, theology
#
# Libro 134:
# Título: "¡¡Sáquennos de aquí!!": María Simma responde a esta petición de las benditas ánimas del purgatorio
# Etiquetas reales: ['catholic', 'devotional', 'paused', 'purgatory']
# Etiquetas predichas: []
# Comparación coloreada: catholic, devotional, paused, purgatory
#
# Libro 135:
# Título: Catecismo de la Iglesia Católica
# Etiquetas reales: ['catholic', 'devotional', 'dogmas', 'faith', 'nonfiction', 'philosophy', 'reference']
# Etiquetas predichas: ['catholic', 'spirituality', 'theology']
# Comparación coloreada: catholic, devotional, dogmas, faith, nonfiction, philosophy, reference
#
# Libro 136:
# Título: Treatise on Prayer and Meditation
# Etiquetas reales: ['catholic', 'devotional', 'prayer', 'rating-top']
# Etiquetas predichas: ['catholic', 'devotional', 'prayer', 'spirituality', 'theology']
# Comparación coloreada: catholic, devotional, prayer, rating-top
#
# Libro 137:
# Título: Salvaje de corazón: Descubramos el secreto del alma masculina
# Etiquetas reales: ['christianity', 'courage', 'courtship', 'emotional-relationships', 'faith', 'heart', 'marriage', 'masculinity', 'nonfiction', 'selfesteem', 'selfhelp', 'spirituality', 'women']
# Etiquetas predichas: ['catholic', 'theology']
# Comparación coloreada: christianity, courage, courtship, emotional-relationships, faith, heart, marriage, masculinity, nonfiction, selfesteem, selfhelp, spirituality, women
#
# Libro 138:
# Título: Humility of Heart
# Etiquetas reales: ['catholic', 'humility']
# Etiquetas predichas: ['catholic', 'devotional', 'dogmas', 'lifestyle', 'philosophy', 'spirituality', 'theology']
# Comparación coloreada: catholic, humility
#
# Libro 139:
# Título: The Agony And The Ecstasy
# Etiquetas reales: ['art', 'biography', 'classics', 'fiction', 'italy']
# Etiquetas predichas: ['biography', 'catholic', 'classics', 'fiction']
# Comparación coloreada: art, biography, classics, fiction, italy
#
# Libro 140:
# Título: Charles De Foucauld: Explorateur Mystique
# Etiquetas reales: ['africa', 'biography', 'catholic', 'france', 'humility', 'misticism', 'monks', 'poverty', 'saints']
# Etiquetas predichas: ['biography', 'catholic', 'conversions', 'religion', 'theology']
# Comparación coloreada: africa, biography, catholic, france, humility, misticism, monks, poverty, saints
#
# Libro 141:
# Título: The Smurfs #6: The Smurfs and the Howlibird (The Smurfs Graphic Novels)
# Etiquetas reales: ['children', 'comics', 'fiction']
# Etiquetas predichas: ['children', 'comics', 'fiction']
# Comparación coloreada: children, comics, fiction
#
# Libro 142:
# Título: Version Control with Subversion
# Etiquetas reales: ['programming']
# Etiquetas predichas: ['programming']
# Comparación coloreada: programming
#
# Libro 143:
# Título: Unworried: A Life Without Anxiety
# Etiquetas reales: ['anxiety', 'mental-health', 'miex', 'nonfiction', 'psichology', 'theraphy']
# Etiquetas predichas: ['anxiety', 'christianity', 'mental-health', 'miex', 'nonfiction', 'philosophy', 'suffering', 'theology']
# Comparación coloreada: anxiety, mental-health, miex, nonfiction, psichology, theraphy
#
# Libro 144:
# Título: The Imitation of Mary
# Etiquetas reales: ['catholic', 'devotional', 'virgin-mary']
# Etiquetas predichas: ['biography', 'catholic', 'classics', 'virgin-mary']
# Comparación coloreada: catholic, devotional, virgin-mary
#
# Libro 145:
# Título: Una nueva guía para una vida racional
# Etiquetas reales: ['miex', 'philosophy', 'psichology', 'selfhelp']
# Etiquetas predichas: ['psichology', 'selfhelp']
# Comparación coloreada: miex, philosophy, psichology, selfhelp
#
# Libro 146:
# Título: The Poetics of Space
# Etiquetas reales: ['art', 'philosophy', 'poetry']
# Etiquetas predichas: ['catholic', 'classics', 'poetry']
# Comparación coloreada: art, philosophy, poetry
#
# Libro 147:
# Título: The Inner Voice of Love: A Journey Through Anguish to Freedom
# Etiquetas reales: ['anxiety', 'catholic', 'chastity', 'favorites', 'hope', 'limits', 'love', 'psichology', 'purity', 'spirituality', 'suffering']
# Etiquetas predichas: ['catholic', 'classics', 'philosophy', 'psichology', 'selfhelp']
# Comparación coloreada: anxiety, catholic, chastity, favorites, hope, limits, love, psichology, purity, spirituality, suffering
#
# Libro 148:
# Título: Gaudete et exsultate. Exhortación apostólica sobre la llamada a la santidad en el mundo actual (Documentos MC)
# Etiquetas reales: ['catholic', 'devotional', 'popes']
# Etiquetas predichas: ['catholic', 'devotional', 'nonfiction', 'spirituality', 'theology']
# Comparación coloreada: catholic, devotional, popes
#
# Libro 149:
# Título: Asterix and the Great Divide (Asterix #25)
# Etiquetas reales: ['nan']
# Etiquetas predichas: ['children', 'comics', 'fiction']
# Comparación coloreada: nan
#
# Libro 150:
# Título: El esbirro
# Etiquetas reales: ['biography', 'christianity', 'communism', 'conversions', 'faith', 'martyrdom', 'memoir', 'nonfiction', 'russia', 'testimonies']
# Etiquetas predichas: ['catholic', 'classics', 'communism', 'fiction', 'memoir', 'miex', 'politics', 'russia']
# Comparación coloreada: biography, christianity, communism, conversions, faith, martyrdom, memoir, nonfiction, russia, testimonies
#
# Libro 151:
# Título: The Parable of Joy: Reflections on the Wisdom of the Book of John
# Etiquetas reales: ['christianity', 'gospels', 'miex', 'new-testament', 'parables', 'rating-top', 'saint-john', 'theology']
# Etiquetas predichas: ['catholic', 'christ', 'miex']
# Comparación coloreada: christianity, gospels, miex, new-testament, parables, rating-top, saint-john, theology
#
# Libro 152:
# Título: The Smurfs #7: The Astrosmurf (The Smurfs Graphic Novels)
# Etiquetas reales: ['children', 'comics', 'fiction']
# Etiquetas predichas: ['astronomy', 'children', 'comics', 'fiction', 'science', 'ufo']
# Comparación coloreada: children, comics, fiction
#
# Libro 153:
# Título: Anna Karénina
# Etiquetas reales: ['classics', 'family', 'fiction', 'love', 'masculinity', 'romance', 'russia']
# Etiquetas predichas: ['biography', 'classics', 'nonfiction']
# Comparación coloreada: classics, family, fiction, love, masculinity, romance, russia
#
# Libro 154:
# Título: The Crucified God: 40th Anniversary Edition
# Etiquetas reales: ['protestantism', 'theology']
# Etiquetas predichas: ['catholic', 'christ', 'religion', 'theology']
# Comparación coloreada: protestantism, theology
#
# Libro 155:
# Título: Don Quijote
# Etiquetas reales: ['adventures', 'classics', 'fiction', 'historical-fiction', 'spain']
# Etiquetas predichas: ['classics', 'fiction']
# Comparación coloreada: adventures, classics, fiction, historical-fiction, spain
#
# Libro 156:
# Título: Scrum and XP from the Trenches
# Etiquetas reales: ['programming']
# Etiquetas predichas: ['nonfiction']
# Comparación coloreada: programming
#
# Libro 157:
# Título: Dance of the Photons: From Einstein to Quantum Teleportation
# Etiquetas reales: ['nonfiction', 'philosophy', 'physics', 'science']
# Etiquetas predichas: ['science']
# Comparación coloreada: nonfiction, philosophy, physics, science
#
# Libro 158:
# Título: La Dolorosa Pasión de Nuestro Señor Jesucristo: Ivory Falls Books
# ...
# Etiquetas predichas: ['catholic']
# Comparación coloreada: allegories, anglicanism, christianity, classics, fiction, miex, quarantine, religion, theology
#
# Libro 183:
# Título: Atomic Habits: An Easy & Proven Way to Build Good Habits & Break Bad Ones
# Etiquetas reales: ['audiobooks', 'business', 'health', 'leadership', 'lifestyle', 'nonfiction', 'productivity', 'psichology', 'rating-number-top', 'rating-top', 'science', 'selfhelp']
# Etiquetas predichas: ['psichology', 'selfhelp']
# Comparación coloreada: audiobooks, business, health, leadership, lifestyle, nonfiction, productivity, psichology, rating-number-top, rating-top, science, selfhelp
#
# Libro 184:
# Título: Waiting for God
# Etiquetas reales: ['philosophy', 'theology']
# Etiquetas predichas: ['catholic', 'christianity', 'devotional', 'nonfiction', 'spirituality', 'theology']
# Comparación coloreada: philosophy, theology
#
# Libro 185:
# Título: Write Better: A Lifelong Editor on Craft, Art, and Spirituality
# Etiquetas reales: ['christianity', 'nonfiction', 'writing']
# Etiquetas predichas: ['nonfiction', 'writing']
# Comparación coloreada: christianity, nonfiction, writing
#
# Libro 186:
# Título: The Everest Years: The challenge of the world's highest mountain
# Etiquetas reales: ['adventures', 'asia', 'himalayas', 'mountaineering']
# Etiquetas predichas: ['mountaineering', 'nonfiction']
# Comparación coloreada: adventures, asia, himalayas, mountaineering
#
# Libro 187:
# Título: The CSS Anthology: 101 Essential Tips, Tricks & Hacks
# Etiquetas reales: ['programming']
# Etiquetas predichas: ['catholic']
# Comparación coloreada: programming
#
# Libro 188:
# Título: Faith Versus Fact: Why Science and Religion Are Incompatible
# Etiquetas reales: ['anti-catholics', 'philosophy', 'science']
# Etiquetas predichas: ['philosophy', 'science', 'theology']
# Comparación coloreada: anti-catholics, philosophy, science
#
# Libro 189:
# Título: Un camino inesperado: Desvelando la parábola de El Señor de los Anillos
# Etiquetas reales: ['books', 'catholic', 'fiction', 'film', 'literary-criticism', 'lord-of-the-rings', 'parables', 'tolkien']
# Etiquetas predichas: []
# Comparación coloreada: books, catholic, fiction, film, literary-criticism, lord-of-the-rings, parables, tolkien
#
# Libro 190:
# Título: It's A God Thing: When Miracles Happen to Everyday People
# Etiquetas reales: ['christianity', 'faith', 'inspirational', 'miracles', 'nonfiction', 'ordinary-life', 'present', 'religion', 'testimonies']
# Etiquetas predichas: ['catholic', 'spirituality', 'theology']
# Comparación coloreada: christianity, faith, inspirational, miracles, nonfiction, ordinary-life, present, religion, testimonies
#
# Libro 191:
# Título: Siempre estuvieron ellas: Galería histórica de hispanas memorables
# Etiquetas reales: ['history', 'spain', 'women']
# Etiquetas predichas: ['biography', 'history', 'women']
# Comparación coloreada: history, spain, women
#
# Libro 192:
# Título: La Divina Comedia
# Etiquetas reales: ['allegories', 'beatific-visions', 'catholic', 'classics', 'fiction', 'heaven', 'hell', 'italy', 'medieval', 'miex', 'poetry', 'purgatory', 'rating-number-top', 'symbolism']
# Etiquetas predichas: ['catholic', 'nonfiction', 'religion', 'theology']
# Comparación coloreada: allegories, beatific-visions, catholic, classics, fiction, heaven, hell, italy, medieval, miex, poetry, purgatory, rating-number-top, symbolism
#
# Libro 193:
# Título: Escatología: La muerte y la vida eterna (Biblioteca Herder)
# Etiquetas reales: ['catholic', 'theology']
# Etiquetas predichas: ['philosophy', 'theology']
# Comparación coloreada: catholic, theology
#
# Libro 194:
# Título: La Biblia desenterrada. Una nueva visión arqueológica del antiguo Israel y de los orígenes de sus textos sagrados
# Etiquetas reales: ['anti-catholics', 'archaeology', 'bible', 'israel', 'miex', 'old-testament']
# Etiquetas predichas: ['nonfiction']
# Comparación coloreada: anti-catholics, archaeology, bible, israel, miex, old-testament
#
# Libro 195:
# Título: La Princesa y el Duende
# Etiquetas reales: ['children', 'christianity', 'classics', 'fiction', 'parables', 'short-stories']
# Etiquetas predichas: ['fiction', 'romance', 'women']
# Comparación coloreada: children, christianity, classics, fiction, parables, short-stories
#
# Libro 196:
# Título: Del amor y otros demonios
# Etiquetas reales: []
# Etiquetas predichas: ['catholic', 'classics']
# Comparación coloreada:
#
# Libro 197:
# Título: La conciencia inexplicada
# Etiquetas reales: []
# Etiquetas predichas: ['newage', 'philosophy', 'psichology', 'science']
# Comparación coloreada:
#
# Libro 198:
# Título: Simón, llamado Pedro: tras los pasos de un hombre que sigue a Dios
# Etiquetas reales: ['apostles', 'biography', 'catholic', 'saint-peter', 'saints']
# Etiquetas predichas: ['catholic', 'christ', 'fiction', 'theology']
# Comparación coloreada: apostles, biography, catholic, saint-peter, saints
#
# Libro 199:
# Título: Sobre la muerte y los moribundos: Una lección de vida para médicos, enfermeras y familias
# Etiquetas reales: ['acceptance', 'comfort', 'death', 'depression', 'healing', 'health', 'loneliness', 'mortification', 'psichology', 'selfhelp', 'suffering']
# Etiquetas predichas: ['catholic', 'death', 'health', 'psichology', 'suffering', 'testimonies']
# Comparación coloreada: acceptance, comfort, death, depression, healing, health, loneliness, mortification, psichology, selfhelp, suffering
#
# Libro 200:
# Título: La guia optima para el ayuno de Daniel: Mas de 100 recetas y 21 devocionales diarios
# Etiquetas reales: ['bible', 'christianity', 'fasting', 'gastronomy', 'health', 'lent', 'prophets', 'selfhelp', 'spirituality']
# Etiquetas predichas: ['catholic', 'nonfiction']
# Comparación coloreada: bible, christianity, fasting, gastronomy, health, lent, prophets, selfhelp, spirituality
#
# Libro 201:
# Título: Carta Encíclica Redemptor Hominis (Encíclicas do Papa João Paulo II, #1)
# Etiquetas reales: ['catholic', 'christ', 'encyclicals', 'faith', 'nonfiction', 'popes', 'redemption', 'saint-john-paul-ii', 'suffering', 'theology', 'vatican']
# Etiquetas predichas: ['catholic']
# Comparación coloreada: catholic, christ, encyclicals, faith, nonfiction, popes, redemption, saint-john-paul-ii, suffering, theology, vatican
#
# Libro 202:
# Título: Augustine of Hippo: A Biography
# Etiquetas reales: ['biography', 'catholic', 'church-history', 'saints', 'theology']
# Etiquetas predichas: ['nonfiction', 'philosophy', 'theology']
# Comparación coloreada: biography, catholic, church-history, saints, theology
#
# Libro 203:
# Título: Don Quijote De La Mancha. Primera Parte
# Etiquetas reales: []
# Etiquetas predichas: ['biography', 'catholic', 'fiction']
# Comparación coloreada:
#
# Libro 204:
# Título: Walking from East to West: God in the Shadows
# Etiquetas reales: ['biography']
# Etiquetas predichas: ['biography']
# Comparación coloreada: biography
#
# Libro 205:
# Título: ¡Libera tu cuerpo! La quiebra de la dieta totalitaria. Cómo adelgazar sin hacer régimen
# Etiquetas reales: ['communism', 'history', 'politics']
# Etiquetas predichas: ['nonfiction', 'politics']
# Comparación coloreada: communism, history, politics
#
# Libro 206:
# Título: Las virtudes fundamentales (Pensamiento Actual)
# Etiquetas reales: ['anglicanism', 'anthropology', 'catholic', 'devotional', 'faith', 'hope', 'love', 'morality', 'philosophy', 'psichology', 'religion', 'spirituality', 'theology', 'virtues']
# Etiquetas predichas: ['catholic', 'nonfiction', 'philosophy', 'theology']
# Comparación coloreada: anglicanism, anthropology, catholic, devotional, faith, hope, love, morality, philosophy, psichology, religion, spirituality, theology, virtues
#
# Libro 207:
# Título: The Crystal Horizon: Everest-The First Solo Ascent
# Etiquetas reales: ['mountaineering']
# Etiquetas predichas: ['memoir', 'mountaineering', 'nonfiction', 'space', 'travel']
# Comparación coloreada: mountaineering
#
# Libro 208:
# Título: Green Smoothie Recipes For Weight Loss and Detox Book
# Etiquetas reales: ['gastronomy', 'healing', 'health', 'recipes']
# Etiquetas predichas: ['gastronomy']
# Comparación coloreada: gastronomy, healing, health, recipes
#
# Libro 209:
# Título: Salt, Not Honey: For a Faith That Stings
# Etiquetas reales: ['baptism', 'catholic', 'charity', 'faith', 'hope', 'job', 'virtues']
# Etiquetas predichas: ['catholic', 'devotional', 'philosophy', 'spirituality', 'theology']
# Comparación coloreada: baptism, catholic, charity, faith, hope, job, virtues
#
# Libro 210:
# Título: Saint Catherine Laboure: of the Miraculous Medal
# Etiquetas reales: ['biography', 'catholic', 'france', 'illustrated', 'nonfiction', 'nuns', 'religion', 'saints', 'spirituality', 'virgin-mary']
# Etiquetas predichas: ['biography', 'catholic', 'france', 'nuns', 'saints', 'women']
# Comparación coloreada: biography, catholic, france, illustrated, nonfiction, nuns, religion, saints, spirituality, virgin-mary
#
# Libro 211:
# Título: Catholic Tales for Boys and Girls
# Etiquetas reales: ['catholic', 'children', 'comics', 'fiction', 'illustrated', 'short-stories', 'theology']
# Etiquetas predichas: ['catholic', 'women']
# Comparación coloreada: catholic, children, comics, fiction, illustrated, short-stories, theology
#
# Libro 212:
# Título: The Smurfs #3: The Smurf King (The Smurfs Graphic Novels)
# Etiquetas reales: ['children', 'comics', 'fiction']
# Etiquetas predichas: ['children', 'comics', 'fiction']
# Comparación coloreada: children, comics, fiction
#
# Libro 213:
# Título: Death On A Friday Afternoon: Meditations On The Last Words Of Jesus From The Cross
# Etiquetas reales: ['ars-moriendi', 'catholic', 'challenging-read', 'christ', 'christianity', 'death', 'fragility', 'lamentations', 'lent', 'martyrdom', 'meditations', 'mortification', 'new-testament', 'passion-of-christ', 'spirituality', 'thirst', 'words']
# Etiquetas predichas: ['catholic', 'christ', 'christianity', 'death', 'devotional', 'lent', 'theology']
# Comparación coloreada: ars-moriendi, catholic, challenging-read, christ, christianity, death, fragility, lamentations, lent, martyrdom, meditations, mortification, new-testament, passion-of-christ, spirituality, thirst, words
#
# Libro 214:
# Título: Our Lady Of Fatima
# Etiquetas reales: ['20th-century', 'apparitions', 'beatific-visions', 'beatified', 'church-history', 'faith', 'fatima', 'historical', 'history', 'holiness', 'miracles', 'nonfiction', 'portugal', 'prayer', 'spirituality', 'theology', 'virgin-mary', 'witnesses']
# Etiquetas predichas: ['apparitions', 'catholic', 'portugal', 'virgin-mary']
# Comparación coloreada: 20th-century, apparitions, beatific-visions, beatified, church-history, faith, fatima, historical, history, holiness, miracles, nonfiction, portugal, prayer, spirituality, theology, virgin-mary, witnesses
#
# Libro 215:
# Título: Good News About Sex & Marriage: Answers to Your Honest Questions about Catholic Teaching
# Etiquetas reales: ['marriage', 'sexuality']
# Etiquetas predichas: ['catholic']
# Comparación coloreada: marriage, sexuality
#
# Libro 216:
# Título: Ortodoxia
# Etiquetas reales: ['apologetics', 'catholic', 'classics', 'creed', 'dogmas', 'essays', 'faith', 'favorites', 'memoir', 'philosophy', 'spirituality', 'uk']
# Etiquetas predichas: ['biography', 'classics', 'fiction', 'philosophy', 'psichology']
# Comparación coloreada: apologetics, catholic, classics, creed, dogmas, essays, faith, favorites, memoir, philosophy, spirituality, uk
#
# Libro 217:
# Título: Revelations of Divine Love
# Etiquetas reales: ['christianity', 'classics', 'death', 'dialogues-with-christ', 'history', 'medieval', 'misticism', 'nonfiction', 'religion', 'revelation', 'spirituality', 'suffering', 'theology', 'uk', 'visions', 'women']
# Etiquetas predichas: ['catholic', 'christianity', 'religion', 'spirituality', 'theology']
# Comparación coloreada: christianity, classics, death, dialogues-with-christ, history, medieval, misticism, nonfiction, religion, revelation, spirituality, suffering, theology, uk, visions, women
#
# Libro 218:
# Título: High Adventure: The True Story of the First Ascent of Everest
# Etiquetas reales: ['himalayas', 'mountaineering']
# Etiquetas predichas: ['asia', 'christianity', 'memoir', 'mountaineering', 'nonfiction', 'travel']
# Comparación coloreada: himalayas, mountaineering
#
# Libro 219:
# Título: Nacemos para no morir nunca (Palabra Hoy)
# Etiquetas reales: ['catholic', 'death', 'heaven', 'illness', 'italy', 'suffering', 'testimonies']
# Etiquetas predichas: ['fiction', 'italy']
# Comparación coloreada: catholic, death, heaven, illness, italy, suffering, testimonies
#
# Libro 220:
# Título: Jesus Remembered: Christianity in the Making, Volume 1
# Etiquetas reales: ['christ', 'church-history', 'protestantism', 'theology']
# Etiquetas predichas: ['new-testament', 'theology']
# Comparación coloreada: christ, church-history, protestantism, theology
#
# Libro 221:
# Título: Lord of the Elves and Eldils: Fantasy and Philosophy in C.S. Lewis and J.R.R. Tolkien
# Etiquetas reales: ['literary-criticism', 'lord-of-the-rings', 'nonfiction', 'philosophy']
# Etiquetas predichas: ['christianity', 'fantasy', 'fiction', 'mithology', 'philosophy', 'religion']
# Comparación coloreada: literary-criticism, lord-of-the-rings, nonfiction, philosophy
#
# Libro 222:
# Título: Los fundamentos del Islam
# Etiquetas reales: ['islamism']
# Etiquetas predichas: ['philosophy']
# Comparación coloreada: islamism
#
# Libro 223:
# Título: Scienziati in tonaca: Da Copernico, padre dell'eliocentrismo, a Lemaître, padre del Big Bang
# Etiquetas reales: ['astronomy', 'catholic', 'creation', 'italy', 'science', 'space', 'theology']
# Etiquetas predichas: ['philosophy', 'science']
# Comparación coloreada: astronomy, catholic, creation, italy, science, space, theology
#
# Libro 224:
# Título: Vida de Maximiliano Kolbe
# Etiquetas reales: ['biography', 'poland']
# Etiquetas predichas: ['biography', 'catholic', 'suffering']
# Comparación coloreada: biography, poland
#
# Libro 225:
# Título: El Abandono en la Divina Providencia: Clásicos Católicos
# Etiquetas reales: ['abandonment-in-god', 'catholic', 'christ', 'classics', 'death', 'devotional', 'eternity', 'faith', 'favorites', 'heart', 'holiness', 'holy-spirit', 'humility', 'mental-health', 'miex', 'nonfiction', 'obedience', 'perspectives', 'present', 'religion', 'selfhelp', 'silence', 'simplicity', 'spirituality', 'suffering', 'theology', 'vocation']
# Etiquetas predichas: ['catholic', 'devotional', 'theology']
# Comparación coloreada: abandonment-in-god, catholic, christ, classics, death, devotional, eternity, faith, favorites, heart, holiness, holy-spirit, humility, mental-health, miex, nonfiction, obedience, perspectives, present, religion, selfhelp, silence, simplicity, spirituality, suffering, theology, vocation
#
# Libro 226:
# Título: El poder del mito
# Etiquetas reales: ['history', 'mithology', 'philosophy', 'psichology', 'theology']
# Etiquetas predichas: []
# Comparación coloreada: history, mithology, philosophy, psichology, theology
#
# Libro 227:
# Título: Tell Me the Stories of Jesus: The Explosive Power of Jesus’ Parables
# Etiquetas reales: ['christ', 'christianity', 'evangelicals', 'parable-of-the-prodigal-son', 'parables']
# Etiquetas predichas: ['christ', 'christianity', 'new-testament']
# Comparación coloreada: christ, christianity, evangelicals, parable-of-the-prodigal-son, parables
#
# Libro 228:
# Título: La Cena Secreta
# Etiquetas reales: ['fiction']
# Etiquetas predichas: ['art', 'catholic', 'lent', 'theology']
# Comparación coloreada: fiction
#
# Libro 229:
# Título: Scarlet Pimpernel of the Vatican (Fontana books)
# Etiquetas reales: []
# Etiquetas predichas: ['biography', 'catholic', 'fiction']
# Comparación coloreada:
#
# Libro 230:
# Título: Inductive Bible Study: Observation, Interpretation, and Application through the Lenses of History, Literature, and Theology
# Etiquetas reales: ['bible', 'evangelicals', 'exegesis']
# Etiquetas predichas: ['bible', 'christianity', 'church-history', 'nonfiction', 'philosophy', 'spirituality', 'theology']
# Comparación coloreada: bible, evangelicals, exegesis
#
# Libro 231:
# Título: Diálogo en torno a la república
# Etiquetas reales: ['catholic', 'politics']
# Etiquetas predichas: []
# Comparación coloreada: catholic, politics
#
# Libro 232:
# Título: Dialogues des carmélites
# Etiquetas reales: ['catholic']
# Etiquetas predichas: ['catholic', 'classics', 'history']
# Comparación coloreada: catholic

# %%
# Ignorar los warnings de métricas indefinidas
warnings.filterwarnings("ignore", category=UndefinedMetricWarning)

limit_tags = 30

# Gráfica con las etiquetas con un mejor f1-score
f1_scores = []
for i, tag in enumerate(mlb.classes_):
    report = classification_report(Y_test[:, i], Y_pred[:, i], output_dict=True, zero_division=0)
    # Check if the key '1' exists in the report
    if '1' in report:
        f1 = report['1']['f1-score']
    else:
        f1 = 0.0  # Default value if class '1' is not present
    f1_scores.append((tag, f1))

# Ordenar las etiquetas por F1-score en orden descendente y tomar las 20 primeras
f1_scores = sorted(f1_scores, key=lambda x: x[1], reverse=True)[:limit_tags]
tags, scores = zip(*f1_scores)

# Crear la carpeta si no existe
output_dir = '../img'
os.makedirs(output_dir, exist_ok=True)

# Crear la gráfica
plt.figure(figsize=(12, 8))
bars = plt.barh(tags, scores, color='skyblue', edgecolor='black')

# Añadir divisiones grises claras
plt.grid(axis='x', linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# Añadir etiquetas con los valores al final de cada barra
for bar, score in zip(bars, scores):
    plt.text(bar.get_width() + 0.01, bar.get_y() + bar.get_height() / 2, 
             f'{score:.2f}', va='center', fontsize=10, color='black')

# Configurar etiquetas y título
plt.xlabel('F1-Score', fontsize=12)
plt.title(f'Top {limit_tags} F1-Scores por Etiqueta', fontsize=14)
plt.gca().invert_yaxis()  # Invertir el eje Y para que el mayor F1-score esté arriba

# Guardar la gráfica
plt.tight_layout()
plt.savefig(os.path.join(output_dir, 'f1_score_per_tag.jpg'))
plt.show()

# %%
# Mostrar ROC AUC para las 30 etiquetas con mejor F1-score

# Crear la carpeta si no existe
os.makedirs(output_dir, exist_ok=True)

# Crear la gráfica
plt.figure(figsize=(10, 6))
for tag in tags:
    i = np.where(mlb.classes_ == tag)[0][0]
    fpr, tpr, _ = roc_curve(Y_test[:, i], Y_pred[:, i])
    auc = roc_auc_score(Y_test[:, i], Y_pred[:, i])
    plt.plot(fpr, tpr, label=f'{tag} (AUC = {auc:.2f})')

plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC Curve for Top {limit_tags} Tags')
# Grid with a gray color dash line
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)
# Put the legend on the left side of the graph
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Guardar la gráfica
plt.savefig(os.path.join(output_dir, 'roc_curve_per_tag.jpg'))
plt.show()

# %% [markdown]
# ## Curva ROC por etiqueta (Top-N)

# %%
top_n = 15  # Cambia según necesidad
fig, ax = plt.subplots(figsize=(10, 8))

for i in range(top_n):
    tag = tags[i]
    y_true = Y_test[:, mlb.classes_.tolist().index(tag)]
    y_score = clf.predict_proba(X_test_embeddings)[mlb.classes_.tolist().index(tag)][:, 1]
    
    fpr, tpr, _ = roc_curve(y_true, y_score)
    roc_auc = sklearn_auc(fpr, tpr)
    
    ax.plot(fpr, tpr, label=f'{tag} (AUC = {roc_auc:.2f})')

ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Curvas ROC por etiqueta (Top-N)')
ax.legend()
plt.tight_layout()
plt.savefig(os.path.join(output_dir, 'roc_curves_top_tags.jpg'))
plt.show()

# %% [markdown]
# ## Matriz de Confusión Multilabel simplificada

# %%
# Histograma con % de libros sobre cada barra
correct_counts = np.sum((Y_pred == Y_test) & (Y_test == 1), axis=1)
total_relevant = np.sum(Y_test, axis=1)
accuracy_per_sample = correct_counts / (total_relevant + 1e-10)

fig, ax = plt.subplots(figsize=(10, 6))
n, bins, patches = ax.hist(accuracy_per_sample, bins=10, color='purple', edgecolor='black')

# Total de libros para calcular porcentajes
total_samples = len(accuracy_per_sample)

# Grid en ambos ejes
ax.grid(axis='both', linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# Etiquetas sobre cada barra: número + porcentaje
for i in range(len(patches)):
    height = n[i]
    if height > 0:
        percent = (height / total_samples) * 100
        ax.text(patches[i].get_x() + patches[i].get_width() / 2,
                height + 1,
                f'{int(height)} ({percent:.1f}%)',
                ha='center', va='bottom', fontsize=10, color='black')

# Títulos y etiquetas
ax.set_title('Distribución de aciertos por muestra', fontsize=14)
ax.set_xlabel('% de etiquetas acertadas', fontsize=12)
ax.set_ylabel('Cantidad de libros', fontsize=12)
plt.tight_layout()
plt.savefig(os.path.join(output_dir, 'accuracy_per_sample_hist.jpg'))
plt.show()

# Imprimir tabla con porcentajes
print("Recuento de libros por intervalo de aciertos:")
for i in range(len(n)):
    low = bins[i]
    high = bins[i+1]
    count = int(n[i])
    percent = (count / total_samples) * 100
    print(f"  {low:.1f} - {high:.1f} : {count} ({percent:.1f}%) libros")
# Out:
# Recuento de libros por intervalo de aciertos:
#   0.0 - 0.1 : 106 (45.7%) libros
#   0.1 - 0.2 : 34 (14.7%) libros
#   0.2 - 0.3 : 26 (11.2%) libros
#   0.3 - 0.4 : 14 (6.0%) libros
#   0.4 - 0.5 : 24 (10.3%) libros
#   0.5 - 0.6 : 5 (2.2%) libros
#   0.6 - 0.7 : 3 (1.3%) libros
#   0.7 - 0.8 : 3 (1.3%) libros
#   0.8 - 0.9 : 1 (0.4%) libros
#   0.9 - 1.0 : 16 (6.9%) libros

# %% [markdown]
# ### 🎯 ¿Cuántas etiquetas acertó el modelo por libro?
#
# Analizamos qué porcentaje de etiquetas reales fue correctamente predicho para cada libro del conjunto de prueba. A continuación, se muestra la distribución:
#
# | Intervalo de aciertos | Libros en ese rango       |
# |------------------------|----------------------------|
# | 0% - 10%               | 106 (45.7%) libros         |
# | 10% - 20%              | 34 (14.7%) libros          |
# | 20% - 30%              | 26 (11.2%) libros          |
# | 30% - 40%              | 14 (6.0%) libros           |
# | 40% - 50%              | 24 (10.3%) libros          |
# | 50% - 60%              | 5 (2.2%) libros            |
# | 60% - 70%              | 3 (1.3%) libros            |
# | 70% - 80%              | 3 (1.3%) libros            |
# | 80% - 90%              | 1 (0.4%) libros            |
# | 90% - 100%             | 16 (6.9%) libros           |
#
# ---
#
# ### 📌 Conclusiones clave
#
# - 🔻 Casi la mitad de los libros (**45.7%**) tuvieron menos del **10%** de sus etiquetas reales correctamente predichas.
# - 🎯 Solo un pequeño grupo (**6.9%**) fue etiquetado **casi perfectamente** (más del 90% de acierto).
# - 🟣 Un porcentaje intermedio de libros (aprox. **28.2%**) recibió entre un **20% y 50%** de etiquetas acertadas, lo que sugiere que el modelo está parcialmente captando el contenido en muchos casos.
#
# ---
#
# ### 🧠 ¿Qué nos dice esto?
#
# - El modelo **funciona bien en algunos casos**, pero **tiende a ser conservador**, dejando muchas etiquetas sin asignar.
# - Este tipo de comportamiento es **típico en tareas multilabel**, especialmente si hay **desbalance de clases** o si las etiquetas tienen **significados sutiles o solapados**.
# - Hay oportunidades claras para mejorar:
#   - Ajustar el umbral de predicción.
#   - Entrenar con más datos.
#   - Trabajar con estrategias de balanceo o ponderación.

# %% [markdown]
# ## Precision-Recall por etiqueta (Top-N)

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score

fig, ax = plt.subplots(figsize=(10, 8))

for i in range(top_n):
    tag = tags[i]
    y_true = Y_test[:, mlb.classes_.tolist().index(tag)]
    y_score = clf.predict_proba(X_test_embeddings)[mlb.classes_.tolist().index(tag)][:, 1]
    
    precision, recall, _ = precision_recall_curve(y_true, y_score)
    avg_precision = average_precision_score(y_true, y_score)
    
    ax.plot(recall, precision, label=f'{tag} (AP = {avg_precision:.2f})')

ax.set_xlabel('Recall')
ax.set_ylabel('Precision')
ax.set_title('Precision-Recall Curve por etiqueta (Top-N)')
ax.legend()
plt.tight_layout()
plt.savefig(os.path.join(output_dir, 'precision_recall_curves.jpg'))
plt.show()

# %% [markdown]
# ## Cobertura de etiquetas reales vs predichas

# %%
# Gráfico comparando cobertura de etiquetas reales vs predichas
true_tag_count = np.sum(Y_test)
pred_tag_count = np.sum(Y_pred)

labels = ['Etiquetas Reales', 'Etiquetas Predichas']
counts = [true_tag_count, pred_tag_count]

plt.figure(figsize=(8, 6))
bars = plt.bar(labels, counts, color=['green', 'orange'], edgecolor='black')

# Añadir líneas de grid horizontales
plt.grid(axis='y', linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# Etiquetas con porcentaje sobre cada barra
total = max(counts)
for bar, count in zip(bars, counts):
    percent = (count / total) * 100
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + total * 0.02,
             f'{count:.0f} ({percent:.1f}%)', ha='center', fontsize=11)

plt.title('Cobertura de etiquetas: Reales vs Predichas', fontsize=14)
plt.ylabel('Cantidad total de etiquetas', fontsize=12)
plt.tight_layout()
plt.savefig(os.path.join(output_dir, 'label_coverage_comparison.jpg'))
plt.show()

# %% [markdown]
# ### 📊 Cobertura de Etiquetas: ¿Cuánto predijo bien el modelo?
#
# - En el conjunto de prueba (20% de los libros), había un total de **1312 etiquetas reales**.
# - El modelo logró predecir correctamente **355 etiquetas**, lo que representa un **27.1%** del total.
#
# ---
#
# ### ✅ ¿Qué significa esto?
#
# - El modelo **está captando parte del significado de los textos**, pero **todavía deja muchas etiquetas sin predecir**.
# - Esto **no es necesariamente malo** en multilabel: es común que un modelo sea **conservador** para evitar errores.
# - **Mejorando el umbral**, los datos o el modelo podríamos aumentar esta cobertura.
#
# ---
#
# ### 🧠 ¿Y ahora qué?
#
# - Analizar etiquetas frecuentes que nunca se predicen (¿quizás faltan ejemplos de ellas?).
# - Evaluar si el **umbral de 0.3** es demasiado alto o bajo para este caso.
# - Podríamos usar un modelo más complejo, más datos, o técnicas como **data augmentation** o **re-balanceo de clases**.

# %% [markdown]
# ## Cross Validation

# %%
# %%
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score
import shutil

# Recalcular binarizador para tener todas las clases actualizadas y sincronizadas
mlb = MultiLabelBinarizer()
Y = mlb.fit_transform(df['tags'])  # Recalcula Y con todas las clases
mlb_classes = mlb.classes_         # Guardamos esto para usar en cada fold

# Generar embeddings (ya se generaron antes, pero aseguramos que están)
# (Puedes comentar esta línea si ya has generado antes `X_embeddings`)
# X_embeddings = model.encode(df['text'].tolist(), show_progress_bar=True)

n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
all_f1_scores = []

for fold, (train_index, val_index) in enumerate(kf.split(X_embeddings)):
    print(f"\n--- Fold {fold+1}/{n_splits} ---")

    X_train_fold = X_embeddings[train_index]
    Y_train_fold = Y[train_index]
    X_val_fold = X_embeddings[val_index]
    Y_val_fold = Y[val_index]

    # Verificar etiquetas válidas en el fold
    valid_labels = np.any(Y_train_fold, axis=0) & np.any(~Y_train_fold, axis=0)
    Y_train_fold = Y_train_fold[:, valid_labels]
    Y_val_fold = Y_val_fold[:, valid_labels]
    fold_classes = mlb_classes[valid_labels]

    # Entrenamiento
    clf_fold = MultiOutputClassifier(LogisticRegression(max_iter=1000))
    clf_fold.fit(X_train_fold, Y_train_fold)

    # Evaluación
    Y_pred_fold = clf_fold.predict(X_val_fold)
    f1 = f1_score(Y_val_fold, Y_pred_fold, average='micro')
    all_f1_scores.append(f1)
    print(f"F1 micro: {f1:.4f}")

    # Guardar modelo y etiquetas
    fold_model_dir = f"../model/cv_fold_{fold+1}"
    # os.makedirs(fold_model_dir, exist_ok=True)
    # joblib.dump(clf_fold, os.path.join(fold_model_dir, "model.joblib"))
    # joblib.dump(valid_labels, os.path.join(fold_model_dir, "valid_labels.joblib"))
    # joblib.dump(fold_classes, os.path.join(fold_model_dir, "classes.joblib"))

# Promedio del rendimiento
avg_f1 = np.mean(all_f1_scores)
print(f"\n✅ F1 promedio (micro) tras {n_splits} folds: {avg_f1:.4f}")
# Out:
# --- Fold 1/5 ---
# F1 micro: 0.2555
#
# --- Fold 2/5 ---
# F1 micro: 0.2308
#
# --- Fold 3/5 ---
# F1 micro: 0.2306
#
# --- Fold 4/5 ---
# F1 micro: 0.2515
#
# --- Fold 5/5 ---
# F1 micro: 0.2451
#
# ✅ F1 promedio (micro) tras 5 folds: 0.2427

# %% [markdown]
# ## 🧠 ¿Qué estamos viendo?
#
# - El **cross-validation** con `KFold` dio un **F1-micro promedio de `0.2427`**.
# - En el split simple del **80/20**, el `classification_report` indica un **F1-micro de `0.26` (aprox.)**, tanto en el `micro avg` como en `samples avg`.
#
# ---
#
# ## 🤔 ¿Qué significa esto?
#
# ### 🔎 Sobre el F1-micro:
# - El F1-micro **tiene en cuenta todas las etiquetas por igual** y **se enfoca en el total de aciertos frente a errores**.
# - Va de **0 a 1**, y **cuanto más alto, mejor**.
#
# ---
#
# ### 📉 ¿Ha mejorado el modelo con cross-validation?
#
# **No realmente.**
# - El resultado de `cross-validation` fue *ligeramente inferior* a tu split original.
# - Esto **no significa que el modelo sea peor**, sino que el **cross-validation te está mostrando una evaluación más robusta y realista**.
# - Es común que el F1 en un solo split (como el 80/20) dé un valor **optimista**, mientras que `k-fold` da una media más honesta, al probar distintos cortes de los datos.
#
# ---
#
# ## 💡 ¿Qué puede estar pasando?
#
# 1. **Desbalance severo de etiquetas**:
#    - Muchas etiquetas tienen *muy pocos ejemplos* (1, 2, 3 muestras). Esto hace que el modelo no aprenda bien sobre ellas.
#    - Esto lo confirma el `support = 0` o `1` en muchas clases del `classification_report`.
#
# 2. **Etiquetas poco frecuentes no generalizan**:
#    - En cada fold, algunas etiquetas quedan **sin ningún ejemplo** en entrenamiento.
#    - Esto impide que se puedan predecir correctamente y **afecta el F1 global**.
#
# 3. **Multilabel + pocos datos por etiqueta = difícil**:
#    - Este problema es típico en multilabel con muchos posibles valores y baja frecuencia por clase.
#
# ---
#
# ## ✅ Conclusiones
#
# | Aspecto                          | Valoración                          |
# |----------------------------------|--------------------------------------|
# | ¿El F1 micro ha subido?          | ❌ No, ha bajado un poco             |
# | ¿El modelo es ahora más robusto? | ✅ Sí, porque se probó en varios splits |
# | ¿Deberías usar cross-validation? | ✅ Totalmente, aunque sea más lento  |
# | ¿Necesitas mejorar algo más?     | ✅ Sí, el dataset y el balanceado de etiquetas |
#
# ---
#
# ## 🔧 Próximos pasos recomendados
#
# 1. **Filtrar etiquetas con muy bajo support (<5 muestras)**.
# 2. **Agrupar etiquetas similares** si algunas son redundantes.
# 3. **Aumentar los datos** (más libros, más etiquetas).
# 4. **Balancear las clases** con técnicas como:
#    - Oversampling (SMOTE multilabel)
#    - Ponderación de clases en `LogisticRegression(class_weight='balanced')`
# 5. **Ajustar el umbral de predicción** dinámicamente en función del recall/precision.

# %%
# %%
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score
from sklearn.utils.class_weight import compute_class_weight

# Paso 1: Filtrar etiquetas poco frecuentes (menos de 5 apariciones en total)
min_freq = 5
tag_counts = pd.Series(df['tags'].explode()).value_counts()
valid_tags = tag_counts[tag_counts >= min_freq].index.tolist()

df['filtered_tags'] = df['tags'].apply(lambda tags: [tag for tag in tags if tag in valid_tags])

# Paso 2: Recalcular multilabel binarización con solo etiquetas válidas
mlb = MultiLabelBinarizer()
Y = mlb.fit_transform(df['filtered_tags'])
mlb_classes = mlb.classes_

# Paso 3: Regenerar los embeddings si no los tienes
# (Puedes comentar si ya los tienes)
# X_embeddings = model.encode(df['text'].tolist(), show_progress_bar=True)

# Paso 4: K-Fold con mejoras
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
all_f1_scores = []

for fold, (train_index, val_index) in enumerate(kf.split(X_embeddings)):
    print(f"\n--- Fold {fold+1}/{n_splits} ---")

    X_train_fold = X_embeddings[train_index]
    Y_train_fold = Y[train_index]
    X_val_fold = X_embeddings[val_index]
    Y_val_fold = Y[val_index]

    # Verificar etiquetas válidas por fold
    valid_labels = np.any(Y_train_fold, axis=0) & np.any(~Y_train_fold, axis=0)
    Y_train_fold = Y_train_fold[:, valid_labels]
    Y_val_fold = Y_val_fold[:, valid_labels]
    fold_classes = mlb_classes[valid_labels]

    # Paso 5: Clasificador con balanceo de clases
    base_clfs = []
    for i in range(Y_train_fold.shape[1]):
        y_i = Y_train_fold[:, i]
        classes = np.unique(y_i)
        if len(classes) == 1:
            base_clfs.append(LogisticRegression(max_iter=1000))
        else:
            weights = compute_class_weight('balanced', classes=classes, y=y_i)
            class_weight_dict = dict(zip(classes, weights))
            base_clfs.append(LogisticRegression(max_iter=1000, class_weight=class_weight_dict))

    clf_fold = MultiOutputClassifier(estimator=LogisticRegression(max_iter=1000), n_jobs=-1)
    clf_fold.estimators_ = base_clfs
    clf_fold.fit(X_train_fold, Y_train_fold)

    # Evaluación
    Y_pred_fold = clf_fold.predict(X_val_fold)
    f1 = f1_score(Y_val_fold, Y_pred_fold, average='micro')
    all_f1_scores.append(f1)
    print(f"F1 micro: {f1:.4f}")

    # Guardar modelo del fold
    # fold_model_dir = f"../model/cv_fold_{fold+1}_improved"
    # os.makedirs(fold_model_dir, exist_ok=True)
    # joblib.dump(clf_fold, os.path.join(fold_model_dir, "model.joblib"))
    # joblib.dump(valid_labels, os.path.join(fold_model_dir, "valid_labels.joblib"))
    # joblib.dump(fold_classes, os.path.join(fold_model_dir, "classes.joblib"))

# Resultado global
avg_f1 = np.mean(all_f1_scores)
print(f"\n✅ F1 promedio (micro) mejorado tras {n_splits} folds: {avg_f1:.4f}")

# Guardar el modelo final completo del último fold como referencia general
final_model = clf_fold  # modelo del último fold
final_mlb = MultiLabelBinarizer()
final_mlb.classes_ = fold_classes  # aseguramos que solo incluya las clases válidas del último fold

# Reutiliza el modelo SentenceTransformer ya cargado como `model`
joblib.dump(final_model, '../model/book_tagging_pipeline_cross_validated.joblib')
joblib.dump(final_mlb, '../model/book_tagging_pipeline_mlb_cross_validated.joblib')
joblib.dump(model, '../model/book_tagging_pipeline_sentence_bert_cross_validated.joblib')

print("✅ Nuevo modelo con validación cruzada guardado exitosamente.")
# Out:
# --- Fold 1/5 ---
# F1 micro: 0.2683
#
# --- Fold 2/5 ---
# F1 micro: 0.2431
#
# --- Fold 3/5 ---
# F1 micro: 0.2406
#
# --- Fold 4/5 ---
# F1 micro: 0.2664
#
# --- Fold 5/5 ---
# F1 micro: 0.2578
#
# ✅ F1 promedio (micro) mejorado tras 5 folds: 0.2552
# ✅ Nuevo modelo con validación cruzada guardado exitosamente.
