# %%
import os
import sys

# Agregar el directorio raíz al sys.path
root_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(root_path)

from functions import get_config, get_database_connection, fetch_table_as_dataframe

# Construir la ruta absoluta del archivo config.cfg
config_path = os.path.join(root_path, 'config.cfg')

# Leer configuración
config = get_config(config_path)

# Crear conexión a la base de datos
try:
    engine = get_database_connection(config)
    
    # Consultar la tabla "books" y cargarla en un DataFrame
    df = fetch_table_as_dataframe(engine, "books")
    
    # Mostrar estadísticas descriptivas
    display(df.describe(include='all').T)
except ValueError as e:
    print(f"Error: {e}")
# Out:
#                             count unique  \
# book_id                    2592.0    NaN
# binding_id                 2579.0    NaN
# publisher_id               2345.0    NaN
# title                        2592   2582
# title_without_series         2042   2032
# isbn                         1933   1933
# isbn13                       1923   1923
# number_pages               2531.0    NaN
# publication_day              35.0    NaN
# publication_month            42.0    NaN
# publication_year           2485.0    NaN
# original_publication_year  2038.0    NaN
# link                         2042   2042
# uri                          2042   2042
# image_url                    2042    487
# small_image_url              2042    487
# average_rating             2592.0    NaN
# ratings_count              1974.0    NaN
# text_reviews_count         1545.0    NaN
# blurb                        1160   1152
#
#                                                                          top  \
# ...
